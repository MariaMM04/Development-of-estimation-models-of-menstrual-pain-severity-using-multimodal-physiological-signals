# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

columns_to_study = ['id', 'glucose_value']
df1 = pd.read_csv(r"C:\Users\Maria\TFG\Missing values\glucose_final_cleaned.csv", usecols=columns_to_study)

plt.figure(figsize=(30, 15))
sns.boxplot(data=df1, x='id', y='glucose_value')

plt.title('Glucose Distribution by Participant ID', fontsize=30, pad=20, weight='bold')
plt.xlabel('Participant ID', fontsize=26, labelpad=15)
plt.ylabel('Glucose Value (mg/dL)', fontsize=26, labelpad=15)
plt.xticks(rotation=45, fontsize=20) 
plt.yticks(fontsize=20)
plt.show()

# %%
df_filtered = pd.read_csv(r"C:\Users\Maria\TFG\Missing values\glucose_final_cleaned.csv")

df_final = pd.merge(df_filtered, df_phases, on=['id', 'day_in_study'])

plt.figure(figsize=(10, 6))
sns.boxplot(data=df_final, x='phase', y='glucose_value')

plt.title('Glucose Across Menstrual Phases')
plt.xlabel('Menstrual Cycle Phase')
plt.ylabel('Glucose (mmol/L)')
plt.xticks(rotation=45)

plt.show()

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.signal import find_peaks
df = pd.read_csv(r"C:\Users\Maria\TFG\Missing values\glucose_finalvalues.csv")
df_phases = pd.read_csv(r"C:\Maria\TFG\Levels of pain_Hormones\hormones_and_selfreport.csv")

df_final = pd.merge(df, df_phases, on=['id', 'day_in_study'])

plt.figure(figsize=(10, 6))
sns.boxplot(data=df_final, x='phase', y='glucose_value')

plt.title('Glucose Across Menstrual Phases')
plt.xlabel('Menstrual Cycle Phase')
plt.ylabel('Glucose (mmol/L)')
plt.xticks(rotation=45)

plt.show()
