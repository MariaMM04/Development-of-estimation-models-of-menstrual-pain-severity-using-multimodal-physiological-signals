# %%
from sklearn import svm

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as stats
from sklearn.decomposition import PCA
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler as  StandardScaler
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, classification_report, balanced_accuracy_score
from sklearn.model_selection import KFold, cross_validate, cross_val_score, GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.model_selection import StratifiedKFold
from sklearn.feature_selection import SelectKBest, f_classif, SelectFromModel
from imblearn.pipeline import Pipeline as im_Pipeline
from sklearn.model_selection import StratifiedGroupKFold, cross_val_predict
from sklearn.metrics import roc_curve, confusion_matrix

from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler

# %%
df1 = pd.read_csv("master_tripel_cramps_dataset.csv")

df_clean_og = df1.dropna(subset=[
    "cramps",
    "cramps binary",
    "cramps group",
    "phase",
    "lh",
    "estrogen",
    "nightly_temperature",
    "hr_mean",
    "glucose_median",
    "glucose_std"
]).copy()

cramps_map_menstrual = {
    "Not at all": 0,
    "Very Low/Little": 1,
    "Low": 2,
    "Moderate": 3,
    "High": 4,
    "Very High": 5
}

cramps_map_binary_menstrual = {
    "Low Pain": 0,
    "High Pain": 1,
}

cramps_map_group_menstrual = {
    "No Pain": 0,
    "Low Pain": 1,
    "High Pain": 2,
}

df_clean_og["cramps"] = df_clean_og["cramps"].map(cramps_map_menstrual)
df_clean_og["cramps binary"] = df_clean_og["cramps binary"].map(cramps_map_binary_menstrual)
df_clean_og["cramps group"] = df_clean_og["cramps group"].map(cramps_map_group_menstrual)

df_clean_og = df_clean_og.dropna(subset=["cramps binary"]).copy()
drop_cols = [
    "id",
    "cramps",
    "cramps binary",
    "cramps group",
    "study_interval_x",
    "study_interval_y",
    "day_in_study"
]

X = df_clean_og.drop(columns=drop_cols)
y = df_clean_og["cramps binary"].astype(int)

variables_categoricas = ["phase"]
variables_num = [
    col for col in X.columns
    if col not in variables_categoricas]

# %%
groups = df_clean_og["id"]

cv_outer = StratifiedGroupKFold(
    n_splits=5,
    shuffle=True,
    random_state=42
)

cv_inner = StratifiedGroupKFold(
    n_splits=5,
    shuffle=True,
    random_state=42
)

import pickle 
with open("outer_splits_binary.pkl", "rb") as f:
    outer_splits = pickle.load(f)

def get_best_rho(y_train, y_train_proba_oof, rhos=np.linspace(0.1, 0.9, 17)):

    best_rho = None
    best_f1 = -1

    for rho in rhos:

        y_pred = (y_train_proba_oof >= rho).astype(int)

        f1 = f1_score(y_train, y_pred, average="macro")

        if f1 > best_f1:
            best_f1 = f1
            best_rho = rho

    return best_rho

# %%
param_grid = {"KNN": {
                    "classifier__n_neighbors": [3, 5, 7, 9, 11],
                    "classifier__weights": ["uniform", "distance"],
                    "classifier__metric": ["euclidean", "manhattan"],
                    "feature_selection__k": [5, 10, 15, 20, "all"]}, 
              "LogReg_Youden": {
                    "classifier__C": [0.001, 0.01, 0.1, 1, 10],
                    "classifier__class_weight": ["balanced"],
                    "classifier__penalty": ["l1", "l2"],
                    "feature_selection__k": [5, 10, 15, 20, "all"]},
              "LogReg_Rho": {
                    "classifier__C": [0.001, 0.01, 0.1, 1, 10],
                    "classifier__class_weight": ["balanced"],
                    "classifier__penalty": ["l1", "l2"],
                    "feature_selection__k": [5, 10, 15, 20, "all"]},
              "Random_Forest": {
                    "classifier__n_estimators": [10, 20, 50, 100, 200, 250, 300, 500],
                    "classifier__max_depth": [1, 2, 3, 5, 7, 10],
                    "classifier__min_samples_leaf": [1, 5, 10],
                    "classifier__max_features": ["sqrt", "log2"],
                    "classifier__max_leaf_nodes": [2, 4, 8, 16, 32],
                    "classifier__class_weight": ["balanced"]},
              "SVM":{
                    "classifier__kernel": ["linear","rbf"],
                    "classifier__gamma": ["scale", "auto"],
                    "classifier__C": [0.01, 0.1, 1, 10],
                    "classifier__class_weight": ["balanced"],
                    "feature_selection__k": [5, 10, 15, 20, "all"]}

    }

# %%
model_df = []
type_response_df = []
accuracy_model = []
balanced_accuracy_model = []
f1_macro_model = []
f1_weighted_model = []
AUC_model = []
models = ["KNN", "LogReg_Youden", "LogReg_Rho","Random_Forest","SVM"]


accuracy = np.nan * np.ones((len(models), len(outer_splits)))
balanced_accuracy = np.nan * np.ones((len(models), len(outer_splits)))
f1_macro = np.nan * np.ones((len(models), len(outer_splits)))
f1_weighted = np.nan * np.ones((len(models), len(outer_splits)))
auc = np.nan * np.ones((len(models), len(outer_splits)))

best_params_all = {model: [] for model in models}
selected_features_all = {model: [] for model in models}
thresholds_lr_youden = []
thresholds_lr_rho = []

for j, (train_idx, test_idx) in enumerate(outer_splits):
    X_train = X.iloc[train_idx]
    X_test = X.iloc[test_idx]

    y_train = y.iloc[train_idx]
    y_test = y.iloc[test_idx]

    groups_train = groups.iloc[train_idx]
        
    for (i,model) in enumerate(models):
        preprocessor = ColumnTransformer(
            transformers=[
                ("zscore", StandardScaler(), variables_num),
                ("ohe", OneHotEncoder(handle_unknown="ignore"), variables_categoricas)
        ])
        match model:
            case "LogReg_Youden":
                mdl = LogisticRegression( solver = "saga", max_iter=1000, random_state = 42)
            case "LogReg_Rho":
                mdl = LogisticRegression( solver = "saga", max_iter=1000, random_state = 42)    
            case "Random_Forest":
                mdl = RandomForestClassifier(random_state = 42)
            case "KNN":
                mdl = KNeighborsClassifier()
            case "SVM":
                mdl = svm.SVC(probability = True, random_state = 42)
        if model == "Random_Forest":
            pipeline = im_Pipeline([
                ("preprocessor", preprocessor),
                ("smote", SMOTE(sampling_strategy=0.9,random_state=42)),
                ("undersample", RandomUnderSampler(sampling_strategy=1.0,random_state=42)),
                ("classifier", mdl)])
        else:
            pipeline = im_Pipeline([
                ("preprocessor", preprocessor),
                ("smote", SMOTE(sampling_strategy=0.9,random_state=42)),
                ("undersample", RandomUnderSampler(sampling_strategy=1.0,random_state=42)),
                ("feature_selection", SelectKBest(score_func=f_classif)),
                ("classifier", mdl)])

        grid = GridSearchCV(
                estimator=pipeline,
                param_grid=param_grid[model],
                cv=cv_inner,
                scoring="f1_macro",
                n_jobs=-1)
        
        grid.fit(X_train, y_train, groups=groups_train)
        
        mdl_selected = grid.best_estimator_
        best_params_all[model].append(grid.best_params_)
        
        if model != "Random_Forest":
            feature_names = mdl_selected.named_steps["preprocessor"].get_feature_names_out()
            selector = mdl_selected.named_steps["feature_selection"]
            selected_features = feature_names[selector.get_support()].tolist()
            print(selected_features)
        else:
            selected_features = X_train.columns.tolist()

        selected_features_all[model].append(selected_features)

        if model == "LogReg_Youden":
            y_train_proba_oof = cross_val_predict(
                mdl_selected,
                X_train,
                y_train,
                cv=cv_inner,   # cv_outer, pero aplicado a X_train, y_train, groups_train. no debes hacer es reutilizar outer_splits dentro del GridSearch, porque esos índices son del dataset completo, no de X_train.
                groups=groups_train,
                method="predict_proba",
                n_jobs=-1
            )[:, 1]

            fpr, tpr, thresholds = roc_curve(y_train, y_train_proba_oof)
            youden_index = tpr - fpr
            best_threshold = thresholds[np.argmax(youden_index)]

            thresholds_lr_youden.append(best_threshold)

            mdl_selected.fit(X_train, y_train)
            y_prob = mdl_selected.predict_proba(X_test)[:, 1]
            y_pred = (y_prob >= best_threshold).astype(int)
            
        elif model == "LogReg_Rho":
            y_train_proba_oof = cross_val_predict(mdl_selected, X_train, y_train, cv=cv_inner, groups=groups_train, method="predict_proba", n_jobs=-1)[:, 1]
            rho_threshold = get_best_rho(y_train,y_train_proba_oof, rhos=np.linspace(0.1, 0.9, 17))

            thresholds_lr_rho.append(rho_threshold)

            mdl_selected.fit(X_train, y_train)
            y_prob = mdl_selected.predict_proba(X_test)[:, 1]
            y_pred = (y_prob >= rho_threshold).astype(int)
        else:
            mdl_selected.fit(X_train, y_train)
            y_pred = mdl_selected.predict(X_test)
            y_prob = mdl_selected.predict_proba(X_test)[:, 1]
        
        accuracy[i, j] = accuracy_score(y_test, y_pred)
        balanced_accuracy[i, j] = balanced_accuracy_score(y_test, y_pred)
        f1_macro[i, j] = f1_score(y_test, y_pred, average="macro")
        f1_weighted[i, j] = f1_score(y_test, y_pred, average="weighted")
        auc[i, j] = roc_auc_score(y_test, y_prob)

        cm = confusion_matrix(y_test, y_pred)

        print(f"\n===== Fold {j+1} - {model} -{grid.best_params_} =====")
        print(f"Accuracy: {accuracy[i,j]:.4f}")
        print(f"Balanced Accuracy: {balanced_accuracy[i,j]:.4f}")
        print(f"F1 Macro: {f1_macro[i,j]:.4f}")
        print(f"AUC: {auc[i,j]:.4f}")

        print("\nConfusion matrix:")
        print(cm)

        print("\nClassification report:")
        print(classification_report(y_test, y_pred))
        
for (i,model) in enumerate(models):
    accuracy_model.append(f"{np.mean(accuracy[i,:]):.2f} +- {np.std(accuracy[i,:]):.2f} [{np.min(accuracy[i,:]):.2f} -  {np.max(accuracy[i,:]):.2f}]")
    balanced_accuracy_model.append(f"{np.mean(balanced_accuracy[i,:]):.2f} +- {np.std(balanced_accuracy[i,:]):.2f} [{np.min(balanced_accuracy[i,:]):.2f} -  {np.max(balanced_accuracy[i,:]):.2f}]")
    f1_macro_model.append(f"{np.mean(f1_macro[i,:]):.2f} +- {np.std(f1_macro[i,:]):.2f}  [{np.min(f1_macro[i,:]):.2f}  -   {np.max(f1_macro[i,:]):.2f}]")
    f1_weighted_model.append(f"{np.mean(f1_weighted[i,:]):.2f} +- {np.std(f1_weighted[i,:]):.2f}  [{np.min(f1_weighted[i,:]):.2f}  -   {np.max(f1_weighted[i,:]):.2f}]")
    AUC_model.append(f"{np.mean(auc[i,:]):.2f} +- {np.std(auc[i,:]):.2f}  [ {np.min(auc[i,:]):.2f}  -  {np.max(auc[i,:]):.2f}]")
        
    if i == 0:
        type_response_df.append("cramps")
    else:
        type_response_df.append("")
        
    model_df.append(model)


df_performance_models = pd.DataFrame(np.transpose([type_response_df,model_df,accuracy_model,balanced_accuracy_model,f1_macro_model,f1_weighted_model, AUC_model]), columns=["Type response","Model", "Accuracy","Balanced Accuracy","F1-Score (macro)","F1-Score (weighted)","AUC"])
display(df_performance_models)
# Out:
# ['zscore__hr_min', 'zscore__hr_q_05', 'zscore__hr_q_25', 'ohe__phase_Follicular', 'ohe__phase_Menstrual']
#
# ===== Fold 1 - KNN -{'classifier__metric': 'manhattan', 'classifier__n_neighbors': 11, 'classifier__weights': 'uniform', 'feature_selection__k': 5} =====
# Accuracy: 0.7898
# Balanced Accuracy: 0.6293
# F1 Macro: 0.5481
# AUC: 0.7449
#
# Confusion matrix:
# [[416  95]
#  [ 20  16]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.81      0.88       511
#            1       0.14      0.44      0.22        36
#
#     accuracy                           0.79       547
#    macro avg       0.55      0.63      0.55       547
# weighted avg       0.90      0.79      0.84       547
#
# ['zscore__hr_min', 'zscore__hr_q_05', 'zscore__hr_q_25', 'ohe__phase_Follicular', 'ohe__phase_Menstrual']
#
# ===== Fold 1 - LogReg_Youden -{'classifier__C': 10, 'classifier__class_weight': 'balanced', 'classifier__penalty': 'l2', 'feature_selection__k': 5} =====
# Accuracy: 0.7075
# Balanced Accuracy: 0.7143
# F1 Macro: 0.5319
# AUC: 0.7822
#
# Confusion matrix:
# [[361 150]
#  [ 10  26]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.71      0.82       511
#            1       0.15      0.72      0.25        36
#
#     accuracy                           0.71       547
#    macro avg       0.56      0.71      0.53       547
# weighted avg       0.92      0.71      0.78       547
#
# ['zscore__hr_min', 'zscore__hr_q_05', 'zscore__hr_q_25', 'ohe__phase_Follicular', 'ohe__phase_Menstrual']
#
# ===== Fold 1 - LogReg_Rho -{'classifier__C': 10, 'classifier__class_weight': 'balanced', 'classifier__penalty': 'l2', 'feature_selection__k': 5} =====
# Accuracy: 0.8300
# Balanced Accuracy: 0.7283
# F1 Macro: 0.6120
# AUC: 0.7822
#
# Confusion matrix:
# [[432  79]
#  [ 14  22]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.85      0.90       511
#            1       0.22      0.61      0.32        36
#
#     accuracy                           0.83       547
#    macro avg       0.59      0.73      0.61       547
# weighted avg       0.92      0.83      0.86       547
#
#
# ===== Fold 1 - Random_Forest -{'classifier__class_weight': 'balanced', 'classifier__max_depth': 1, 'classifier__max_features': 'sqrt', 'classifier__max_leaf_nodes': 2, 'classifier__min_samples_leaf': 1, 'classifier__n_estimators': 10} =====
# Accuracy: 0.7806
# Balanced Accuracy: 0.7535
# F1 Macro: 0.5861
# AUC: 0.7957
#
# Confusion matrix:
# [[401 110]
#  [ 10  26]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.78      0.87       511
#            1       0.19      0.72      0.30        36
#
#     accuracy                           0.78       547
#    macro avg       0.58      0.75      0.59       547
# weighted avg       0.92      0.78      0.83       547
#
# ['zscore__hr_min', 'zscore__hr_q_05', 'zscore__hr_q_25', 'ohe__phase_Follicular', 'ohe__phase_Menstrual']
#
# ===== Fold 1 - SVM -{'classifier__C': 10, 'classifier__class_weight': 'balanced', 'classifier__gamma': 'scale', 'classifier__kernel': 'linear', 'feature_selection__k': 5} =====
# Accuracy: 0.7495
# Balanced Accuracy: 0.7110
# F1 Macro: 0.5544
# AUC: 0.7865
#
# Confusion matrix:
# [[386 125]
#  [ 12  24]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.76      0.85       511
#            1       0.16      0.67      0.26        36
#
#     accuracy                           0.75       547
#    macro avg       0.57      0.71      0.55       547
# weighted avg       0.92      0.75      0.81       547
#
# ['zscore__hr_mean', 'zscore__hr_min', 'zscore__hr_q_05', 'zscore__hr_q_25', 'ohe__phase_Menstrual']
#
# ===== Fold 2 - KNN -{'classifier__metric': 'manhattan', 'classifier__n_neighbors': 11, 'classifier__weights': 'uniform', 'feature_selection__k': 5} =====
# Accuracy: 0.7778
# Balanced Accuracy: 0.6817
# F1 Macro: 0.6369
# AUC: 0.7640
#
# Confusion matrix:
# [[416  94]
#  [ 38  46]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.82      0.86       510
#            1       0.33      0.55      0.41        84
#
#     accuracy                           0.78       594
#    macro avg       0.62      0.68      0.64       594
# weighted avg       0.83      0.78      0.80       594
#
# ['zscore__hr_mean', 'zscore__hr_median', 'zscore__hr_cv', 'zscore__hr_min', 'zscore__hr_q_05', 'zscore__hr_q_25', 'zscore__hr_q_75', 'zscore__glucose_mean', 'zscore__glucose_median', 'zscore__glucose_min', 'zscore__glucose_q_25', 'zscore__glucose_q_75', 'zscore__glucose_q_95', 'ohe__phase_Follicular', 'ohe__phase_Menstrual']
#
# ===== Fold 2 - LogReg_Youden -{'classifier__C': 10, 'classifier__class_weight': 'balanced', 'classifier__penalty': 'l2', 'feature_selection__k': 15} =====
# Accuracy: 0.7407
# Balanced Accuracy: 0.7446
# F1 Macro: 0.6402
# AUC: 0.7732
#
# Confusion matrix:
# [[377 133]
#  [ 21  63]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.74      0.83       510
#            1       0.32      0.75      0.45        84
#
#     accuracy                           0.74       594
#    macro avg       0.63      0.74      0.64       594
# weighted avg       0.86      0.74      0.78       594
#
# ['zscore__hr_mean', 'zscore__hr_median', 'zscore__hr_cv', 'zscore__hr_min', 'zscore__hr_q_05', 'zscore__hr_q_25', 'zscore__hr_q_75', 'zscore__glucose_mean', 'zscore__glucose_median', 'zscore__glucose_min', 'zscore__glucose_q_25', 'zscore__glucose_q_75', 'zscore__glucose_q_95', 'ohe__phase_Follicular', 'ohe__phase_Menstrual']
#
# ===== Fold 2 - LogReg_Rho -{'classifier__C': 10, 'classifier__class_weight': 'balanced', 'classifier__penalty': 'l2', 'feature_selection__k': 15} =====
# Accuracy: 0.7963
# Balanced Accuracy: 0.7024
# F1 Macro: 0.6589
# AUC: 0.7732
#
# Confusion matrix:
# [[425  85]
#  [ 36  48]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.83      0.88       510
#            1       0.36      0.57      0.44        84
#
#     accuracy                           0.80       594
#    macro avg       0.64      0.70      0.66       594
# weighted avg       0.84      0.80      0.81       594
#
#
# ===== Fold 2 - Random_Forest -{'classifier__class_weight': 'balanced', 'classifier__max_depth': 10, 'classifier__max_features': 'sqrt', 'classifier__max_leaf_nodes': 16, 'classifier__min_samples_leaf': 10, 'classifier__n_estimators': 100} =====
# Accuracy: 0.7811
# Balanced Accuracy: 0.6538
# F1 Macro: 0.6240
# AUC: 0.7658
#
# Confusion matrix:
# [[424  86]
#  [ 44  40]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.83      0.87       510
#            1       0.32      0.48      0.38        84
#
#     accuracy                           0.78       594
#    macro avg       0.61      0.65      0.62       594
# weighted avg       0.82      0.78      0.80       594
#
# ['zscore__hr_mean', 'zscore__hr_min', 'zscore__hr_q_05', 'zscore__hr_q_25', 'ohe__phase_Menstrual']
#
# ===== Fold 2 - SVM -{'classifier__C': 10, 'classifier__class_weight': 'balanced', 'classifier__gamma': 'auto', 'classifier__kernel': 'rbf', 'feature_selection__k': 5} =====
# Accuracy: 0.7879
# Balanced Accuracy: 0.7273
# F1 Macro: 0.6647
# AUC: 0.7783
#
# Confusion matrix:
# [[414  96]
#  [ 30  54]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.81      0.87       510
#            1       0.36      0.64      0.46        84
#
#     accuracy                           0.79       594
#    macro avg       0.65      0.73      0.66       594
# weighted avg       0.85      0.79      0.81       594
#
# ['zscore__hr_mean', 'zscore__hr_median', 'zscore__hr_cv', 'zscore__hr_min', 'zscore__hr_q_05', 'zscore__hr_q_25', 'zscore__glucose_median', 'zscore__glucose_min', 'ohe__phase_Follicular', 'ohe__phase_Menstrual']
#
# ===== Fold 3 - KNN -{'classifier__metric': 'manhattan', 'classifier__n_neighbors': 7, 'classifier__weights': 'uniform', 'feature_selection__k': 10} =====
# Accuracy: 0.6912
# Balanced Accuracy: 0.5880
# F1 Macro: 0.5799
# AUC: 0.6132
#
# Confusion matrix:
# [[205  61]
#  [ 44  30]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.82      0.77      0.80       266
#            1       0.33      0.41      0.36        74
#
#     accuracy                           0.69       340
#    macro avg       0.58      0.59      0.58       340
# weighted avg       0.72      0.69      0.70       340
#
# ['zscore__hr_mean', 'zscore__hr_median', 'zscore__hr_std', 'zscore__hr_cv', 'zscore__hr_min', 'zscore__hr_q_05', 'zscore__hr_q_25', 'zscore__glucose_mean', 'zscore__glucose_median', 'zscore__glucose_min', 'zscore__glucose_q_05', 'zscore__glucose_q_25', 'zscore__glucose_q_75', 'ohe__phase_Follicular', 'ohe__phase_Menstrual']
#
# ===== Fold 3 - LogReg_Youden -{'classifier__C': 10, 'classifier__class_weight': 'balanced', 'classifier__penalty': 'l1', 'feature_selection__k': 15} =====
# Accuracy: 0.6500
# Balanced Accuracy: 0.6202
# F1 Macro: 0.5822
# AUC: 0.6777
#
# Confusion matrix:
# [[179  87]
#  [ 32  42]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.67      0.75       266
#            1       0.33      0.57      0.41        74
#
#     accuracy                           0.65       340
#    macro avg       0.59      0.62      0.58       340
# weighted avg       0.73      0.65      0.68       340
#
# ['zscore__hr_mean', 'zscore__hr_median', 'zscore__hr_std', 'zscore__hr_cv', 'zscore__hr_min', 'zscore__hr_q_05', 'zscore__hr_q_25', 'zscore__glucose_mean', 'zscore__glucose_median', 'zscore__glucose_min', 'zscore__glucose_q_05', 'zscore__glucose_q_25', 'zscore__glucose_q_75', 'ohe__phase_Follicular', 'ohe__phase_Menstrual']
#
# ===== Fold 3 - LogReg_Rho -{'classifier__C': 10, 'classifier__class_weight': 'balanced', 'classifier__penalty': 'l1', 'feature_selection__k': 15} =====
# Accuracy: 0.7235
# Balanced Accuracy: 0.6185
# F1 Macro: 0.6125
# AUC: 0.6777
#
# Confusion matrix:
# [[214  52]
#  [ 42  32]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.80      0.82       266
#            1       0.38      0.43      0.41        74
#
#     accuracy                           0.72       340
#    macro avg       0.61      0.62      0.61       340
# weighted avg       0.74      0.72      0.73       340
#
#
# ===== Fold 3 - Random_Forest -{'classifier__class_weight': 'balanced', 'classifier__max_depth': 7, 'classifier__max_features': 'sqrt', 'classifier__max_leaf_nodes': 16, 'classifier__min_samples_leaf': 5, 'classifier__n_estimators': 10} =====
# Accuracy: 0.7147
# Balanced Accuracy: 0.5884
# F1 Macro: 0.5871
# AUC: 0.6480
#
# Confusion matrix:
# [[216  50]
#  [ 47  27]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.82      0.81      0.82       266
#            1       0.35      0.36      0.36        74
#
#     accuracy                           0.71       340
#    macro avg       0.59      0.59      0.59       340
# weighted avg       0.72      0.71      0.72       340
#
# ['zscore__lh', 'zscore__estrogen', 'zscore__nightly_temperature', 'zscore__hr_mean', 'zscore__hr_median', 'zscore__hr_std', 'zscore__hr_cv', 'zscore__hr_var', 'zscore__hr_min', 'zscore__hr_max', 'zscore__hr_q_05', 'zscore__hr_q_25', 'zscore__hr_q_75', 'zscore__hr_q_95', 'zscore__glucose_mean', 'zscore__glucose_median', 'zscore__glucose_std', 'zscore__glucose_cv', 'zscore__glucose_var', 'zscore__glucose_min', 'zscore__glucose_max', 'zscore__glucose_q_05', 'zscore__glucose_q_25', 'zscore__glucose_q_75', 'zscore__glucose_q_95', 'ohe__phase_Fertility', 'ohe__phase_Follicular', 'ohe__phase_Luteal', 'ohe__phase_Menstrual']
#
# ===== Fold 3 - SVM -{'classifier__C': 10, 'classifier__class_weight': 'balanced', 'classifier__gamma': 'scale', 'classifier__kernel': 'linear', 'feature_selection__k': 'all'} =====
# Accuracy: 0.7059
# Balanced Accuracy: 0.6023
# F1 Macro: 0.5948
# AUC: 0.6773
#
# Confusion matrix:
# [[209  57]
#  [ 43  31]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.79      0.81       266
#            1       0.35      0.42      0.38        74
#
#     accuracy                           0.71       340
#    macro avg       0.59      0.60      0.59       340
# weighted avg       0.73      0.71      0.71       340
#
# ['zscore__hr_mean', 'zscore__hr_median', 'zscore__hr_cv', 'zscore__hr_min', 'zscore__hr_q_05', 'zscore__hr_q_25', 'zscore__hr_q_75', 'zscore__glucose_q_75', 'ohe__phase_Follicular', 'ohe__phase_Menstrual']
#
# ===== Fold 4 - KNN -{'classifier__metric': 'manhattan', 'classifier__n_neighbors': 9, 'classifier__weights': 'distance', 'feature_selection__k': 10} =====
# Accuracy: 0.6944
# Balanced Accuracy: 0.6276
# F1 Macro: 0.5555
# AUC: 0.6491
#
# Confusion matrix:
# [[324 128]
#  [ 30  35]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.72      0.80       452
#            1       0.21      0.54      0.31        65
#
#     accuracy                           0.69       517
#    macro avg       0.56      0.63      0.56       517
# weighted avg       0.83      0.69      0.74       517
#
# ['zscore__hr_mean', 'zscore__hr_median', 'zscore__hr_cv', 'zscore__hr_min', 'zscore__hr_q_05', 'zscore__hr_q_25', 'zscore__hr_q_75', 'zscore__glucose_q_75', 'ohe__phase_Follicular', 'ohe__phase_Menstrual']
#
# ===== Fold 4 - LogReg_Youden -{'classifier__C': 0.1, 'classifier__class_weight': 'balanced', 'classifier__penalty': 'l2', 'feature_selection__k': 10} =====
# Accuracy: 0.7002
# Balanced Accuracy: 0.7100
# F1 Macro: 0.5900
# AUC: 0.7493
#
# Confusion matrix:
# [[315 137]
#  [ 18  47]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.70      0.80       452
#            1       0.26      0.72      0.38        65
#
#     accuracy                           0.70       517
#    macro avg       0.60      0.71      0.59       517
# weighted avg       0.86      0.70      0.75       517
#
# ['zscore__hr_mean', 'zscore__hr_median', 'zscore__hr_cv', 'zscore__hr_min', 'zscore__hr_q_05', 'zscore__hr_q_25', 'zscore__hr_q_75', 'zscore__glucose_q_75', 'ohe__phase_Follicular', 'ohe__phase_Menstrual']
#
# ===== Fold 4 - LogReg_Rho -{'classifier__C': 0.1, 'classifier__class_weight': 'balanced', 'classifier__penalty': 'l2', 'feature_selection__k': 10} =====
# Accuracy: 0.7660
# Balanced Accuracy: 0.6686
# F1 Macro: 0.6115
# AUC: 0.7493
#
# Confusion matrix:
# [[361  91]
#  [ 30  35]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.80      0.86       452
#            1       0.28      0.54      0.37        65
#
#     accuracy                           0.77       517
#    macro avg       0.60      0.67      0.61       517
# weighted avg       0.84      0.77      0.79       517
#
#
# ===== Fold 4 - Random_Forest -{'classifier__class_weight': 'balanced', 'classifier__max_depth': 7, 'classifier__max_features': 'log2', 'classifier__max_leaf_nodes': 16, 'classifier__min_samples_leaf': 10, 'classifier__n_estimators': 10} =====
# Accuracy: 0.7002
# Balanced Accuracy: 0.6441
# F1 Macro: 0.5653
# AUC: 0.7121
#
# Confusion matrix:
# [[325 127]
#  [ 28  37]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.72      0.81       452
#            1       0.23      0.57      0.32        65
#
#     accuracy                           0.70       517
#    macro avg       0.57      0.64      0.57       517
# weighted avg       0.83      0.70      0.75       517
#
# ['zscore__hr_mean', 'zscore__hr_median', 'zscore__hr_cv', 'zscore__hr_min', 'zscore__hr_q_05', 'zscore__hr_q_25', 'zscore__hr_q_75', 'zscore__glucose_q_75', 'ohe__phase_Follicular', 'ohe__phase_Menstrual']
#
# ===== Fold 4 - SVM -{'classifier__C': 0.1, 'classifier__class_weight': 'balanced', 'classifier__gamma': 'scale', 'classifier__kernel': 'linear', 'feature_selection__k': 10} =====
# Accuracy: 0.7176
# Balanced Accuracy: 0.7265
# F1 Macro: 0.6062
# AUC: 0.7550
#
# Confusion matrix:
# [[323 129]
#  [ 17  48]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.71      0.82       452
#            1       0.27      0.74      0.40        65
#
#     accuracy                           0.72       517
#    macro avg       0.61      0.73      0.61       517
# weighted avg       0.86      0.72      0.76       517
#
# ['zscore__hr_min', 'zscore__hr_q_05', 'ohe__phase_Fertility', 'ohe__phase_Follicular', 'ohe__phase_Menstrual']
#
# ===== Fold 5 - KNN -{'classifier__metric': 'manhattan', 'classifier__n_neighbors': 9, 'classifier__weights': 'uniform', 'feature_selection__k': 5} =====
# Accuracy: 0.7237
# Balanced Accuracy: 0.6340
# F1 Macro: 0.6388
# AUC: 0.7362
#
# Confusion matrix:
# [[339  68]
#  [ 87  67]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.83      0.81       407
#            1       0.50      0.44      0.46       154
#
#     accuracy                           0.72       561
#    macro avg       0.65      0.63      0.64       561
# weighted avg       0.71      0.72      0.72       561
#
# ['zscore__hr_min', 'zscore__hr_q_05', 'ohe__phase_Fertility', 'ohe__phase_Follicular', 'ohe__phase_Menstrual']
#
# ===== Fold 5 - LogReg_Youden -{'classifier__C': 0.01, 'classifier__class_weight': 'balanced', 'classifier__penalty': 'l1', 'feature_selection__k': 5} =====
# Accuracy: 0.7504
# Balanced Accuracy: 0.7130
# F1 Macro: 0.7016
# AUC: 0.7996
#
# Confusion matrix:
# [[324  83]
#  [ 57  97]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.80      0.82       407
#            1       0.54      0.63      0.58       154
#
#     accuracy                           0.75       561
#    macro avg       0.69      0.71      0.70       561
# weighted avg       0.76      0.75      0.76       561
#
# ['zscore__hr_min', 'zscore__hr_q_05', 'ohe__phase_Fertility', 'ohe__phase_Follicular', 'ohe__phase_Menstrual']
#
# ===== Fold 5 - LogReg_Rho -{'classifier__C': 0.01, 'classifier__class_weight': 'balanced', 'classifier__penalty': 'l1', 'feature_selection__k': 5} =====
# Accuracy: 0.7558
# Balanced Accuracy: 0.7489
# F1 Macro: 0.7210
# AUC: 0.7996
#
# Confusion matrix:
# [[311  96]
#  [ 41 113]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.76      0.82       407
#            1       0.54      0.73      0.62       154
#
#     accuracy                           0.76       561
#    macro avg       0.71      0.75      0.72       561
# weighted avg       0.79      0.76      0.77       561
#
#
# ===== Fold 5 - Random_Forest -{'classifier__class_weight': 'balanced', 'classifier__max_depth': 1, 'classifier__max_features': 'sqrt', 'classifier__max_leaf_nodes': 2, 'classifier__min_samples_leaf': 1, 'classifier__n_estimators': 10} =====
# Accuracy: 0.6827
# Balanced Accuracy: 0.5492
# F1 Macro: 0.5496
# AUC: 0.6492
#
# Confusion matrix:
# [[344  63]
#  [115  39]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.75      0.85      0.79       407
#            1       0.38      0.25      0.30       154
#
#     accuracy                           0.68       561
#    macro avg       0.57      0.55      0.55       561
# weighted avg       0.65      0.68      0.66       561
#
# ['zscore__hr_min', 'zscore__hr_q_05', 'ohe__phase_Fertility', 'ohe__phase_Follicular', 'ohe__phase_Menstrual']
#
# ===== Fold 5 - SVM -{'classifier__C': 0.1, 'classifier__class_weight': 'balanced', 'classifier__gamma': 'scale', 'classifier__kernel': 'linear', 'feature_selection__k': 5} =====
# Accuracy: 0.7059
# Balanced Accuracy: 0.5935
# F1 Macro: 0.5986
# AUC: 0.7726
#
# Confusion matrix:
# [[343  64]
#  [101  53]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.77      0.84      0.81       407
#            1       0.45      0.34      0.39       154
#
#     accuracy                           0.71       561
#    macro avg       0.61      0.59      0.60       561
# weighted avg       0.68      0.71      0.69       561
#   Type response          Model                     Accuracy  \
# 0        cramps            KNN  0.74 +- 0.04 [0.69 -  0.79]
# 1                LogReg_Youden  0.71 +- 0.04 [0.65 -  0.75]
# 2                   LogReg_Rho  0.77 +- 0.04 [0.72 -  0.83]
# 3                Random_Forest  0.73 +- 0.04 [0.68 -  0.78]
# 4                          SVM  0.73 +- 0.03 [0.71 -  0.79]
#
#              Balanced Accuracy                F1-Score (macro)  \
# 0  0.63 +- 0.03 [0.59 -  0.68]  0.59 +- 0.04  [0.55  -   0.64]
# 1  0.70 +- 0.04 [0.62 -  0.74]  0.61 +- 0.06  [0.53  -   0.70]
# 2  0.69 +- 0.05 [0.62 -  0.75]  0.64 +- 0.04  [0.61  -   0.72]
# 3  0.64 +- 0.07 [0.55 -  0.75]  0.58 +- 0.03  [0.55  -   0.62]
# 4  0.67 +- 0.06 [0.59 -  0.73]  0.60 +- 0.04  [0.55  -   0.66]
#
#               F1-Score (weighted)                             AUC
# 0  0.76 +- 0.05  [0.70  -   0.84]  0.70 +- 0.06  [ 0.61  -  0.76]
# 1  0.75 +- 0.04  [0.68  -   0.78]  0.76 +- 0.04  [ 0.68  -  0.80]
# 2  0.79 +- 0.05  [0.73  -   0.86]  0.76 +- 0.04  [ 0.68  -  0.80]
# 3  0.75 +- 0.06  [0.66  -   0.83]  0.71 +- 0.06  [ 0.65  -  0.80]
# 4  0.76 +- 0.05  [0.69  -   0.81]  0.75 +- 0.04  [ 0.68  -  0.79]
