# %%
from sklearn import svm

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as stats
from sklearn.decomposition import PCA
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler as  StandardScaler
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, classification_report, balanced_accuracy_score
from sklearn.model_selection import KFold, cross_validate, cross_val_score, GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.model_selection import StratifiedKFold
from sklearn.feature_selection import SelectKBest, f_classif, SelectFromModel
from imblearn.pipeline import Pipeline as im_Pipeline
from sklearn.model_selection import StratifiedGroupKFold, cross_val_predict
from sklearn.metrics import roc_curve, confusion_matrix

# %%
df1 = pd.read_csv("master_tripel_cramps_dataset.csv")

df_clean_og = df1.dropna(subset=[
    "cramps",
    "cramps binary",
    "cramps group",
    "phase",
    "lh",
    "estrogen",
    "nightly_temperature",
    "hr_mean",
    "glucose_median",
    "glucose_std"
]).copy()

cramps_map_menstrual = {
    "Not at all": 0,
    "Very Low/Little": 1,
    "Low": 2,
    "Moderate": 3,
    "High": 4,
    "Very High": 5
}

cramps_map_binary_menstrual = {
    "Low Pain": 0,
    "High Pain": 1,
}

cramps_map_group_menstrual = {
    "No Pain": 0,
    "Low Pain": 1,
    "High Pain": 2,
}

df_clean_og["cramps"] = df_clean_og["cramps"].map(cramps_map_menstrual)
df_clean_og["cramps binary"] = df_clean_og["cramps binary"].map(cramps_map_binary_menstrual)
df_clean_og["cramps group"] = df_clean_og["cramps group"].map(cramps_map_group_menstrual)

df_clean_og = df_clean_og.dropna(subset=["cramps binary"]).copy()
drop_cols = [
    "id",
    "cramps",
    "cramps binary",
    "cramps group",
    "study_interval_x",
    "study_interval_y",
    "day_in_study"
]

X = df_clean_og.drop(columns=drop_cols)
y = df_clean_og["cramps binary"].astype(int)

variables_categoricas = ["phase"]
variables_num = [
    col for col in X.columns
    if col not in variables_categoricas]

# %%
groups = df_clean_og["id"]

cv_outer = StratifiedGroupKFold(
    n_splits=5,
    shuffle=True,
    random_state=42
)

cv_inner = StratifiedGroupKFold(
    n_splits=5,
    shuffle=True,
    random_state=42
)

import pickle 
with open("outer_splits_binary.pkl", "rb") as f:
    outer_splits = pickle.load(f)

def get_best_rho(y_train, y_train_proba_oof, rhos=np.linspace(0.1, 0.9, 17)):

    best_rho = None
    best_f1 = -1

    for rho in rhos:

        y_pred = (y_train_proba_oof >= rho).astype(int)

        f1 = f1_score(y_train, y_pred, average="macro")

        if f1 > best_f1:
            best_f1 = f1
            best_rho = rho

    return best_rho

# %%
param_grid = {"KNN": {
                    "classifier__n_neighbors": [3, 5, 7, 9, 11],
                    "classifier__weights": ["uniform", "distance"],
                    "classifier__metric": ["euclidean", "manhattan"],
                    "feature_selection__k": [5, 10, 15, 20, "all"]}, 
              "LogReg_Youden": {
                    "classifier__C": [0.001, 0.01, 0.1, 1, 10],
                    "classifier__class_weight": ["balanced"],
                    "classifier__penalty": ["l1", "l2"],
                    "feature_selection__k": [5, 10, 15, 20, "all"]},
              "LogReg_Rho": {
                    "classifier__C": [0.001, 0.01, 0.1, 1, 10],
                    "classifier__class_weight": ["balanced"],
                    "classifier__penalty": ["l1", "l2"],
                    "feature_selection__k": [5, 10, 15, 20, "all"]},
              "Random_Forest": {
                    "classifier__n_estimators": [10, 20, 50, 100, 200, 250, 300, 500],
                    "classifier__max_depth": [1, 2, 3, 5, 7, 10],
                    "classifier__min_samples_leaf": [1, 5, 10],
                    "classifier__max_features": ["sqrt", "log2"],
                    "classifier__max_leaf_nodes": [2, 4, 8, 16, 32],
                    "classifier__class_weight": ["balanced"]},
              "SVM":{
                    "classifier__kernel": ["linear","rbf"],
                    "classifier__gamma": ["scale", "auto"],
                    "classifier__C": [0.01, 0.1, 1, 10],
                    "classifier__class_weight": ["balanced"],
                    "feature_selection__k": [5, 10, 15, 20, "all"]}

    }

# %%
model_df = []
type_response_df = []
accuracy_model = []
balanced_accuracy_model = []
f1_macro_model = []
f1_weighted_model = []
AUC_model = []
models = ["KNN", "LogReg_Youden", "LogReg_Rho","Random_Forest","SVM"]


accuracy = np.nan * np.ones((len(models), len(outer_splits)))
balanced_accuracy = np.nan * np.ones((len(models), len(outer_splits)))
f1_macro = np.nan * np.ones((len(models), len(outer_splits)))
f1_weighted = np.nan * np.ones((len(models), len(outer_splits)))
auc = np.nan * np.ones((len(models), len(outer_splits)))

best_params_all = {model: [] for model in models}
selected_features_all = {model: [] for model in models}
thresholds_lr_youden = []
thresholds_lr_rho = []

for j, (train_idx, test_idx) in enumerate(outer_splits):
    X_train = X.iloc[train_idx]
    X_test = X.iloc[test_idx]

    y_train = y.iloc[train_idx]
    y_test = y.iloc[test_idx]

    groups_train = groups.iloc[train_idx]
        
    for (i,model) in enumerate(models):
        preprocessor = ColumnTransformer(
            transformers=[
                ("zscore", StandardScaler(), variables_num),
                ("ohe", OneHotEncoder(handle_unknown="ignore"), variables_categoricas)
        ])
        match model:
            case "LogReg_Youden":
                mdl = LogisticRegression( solver = "saga", max_iter=1000, random_state = 42)
            case "LogReg_Rho":
                mdl = LogisticRegression( solver = "saga", max_iter=1000, random_state = 42)    
            case "Random_Forest":
                mdl = RandomForestClassifier(random_state = 42)
            case "KNN":
                mdl = KNeighborsClassifier()
            case "SVM":
                mdl = svm.SVC(probability = True, random_state = 42)
        if model == "Random_Forest":
            pipeline = Pipeline([
                ("preprocessor", preprocessor),
                ("classifier", mdl)])
        else:
            pipeline = Pipeline([
                ("preprocessor", preprocessor),
                ("feature_selection", SelectKBest(score_func=f_classif)),
                ("classifier", mdl)])

        grid = GridSearchCV(
                estimator=pipeline,
                param_grid=param_grid[model],
                cv=cv_inner,
                scoring="f1_macro",
                n_jobs=-1)
        
        grid.fit(X_train, y_train, groups=groups_train)
        
        mdl_selected = grid.best_estimator_
        best_params_all[model].append(grid.best_params_)
        
        if model != "Random_Forest":
            feature_names = mdl_selected.named_steps["preprocessor"].get_feature_names_out()
            selector = mdl_selected.named_steps["feature_selection"]
            selected_features = feature_names[selector.get_support()].tolist()
            print(selected_features)
        else:
            selected_features = X_train.columns.tolist()

        selected_features_all[model].append(selected_features)

        if model == "LogReg_Youden":
            y_train_proba_oof = cross_val_predict(
                mdl_selected,
                X_train,
                y_train,
                cv=cv_inner,   # cv_outer, pero aplicado a X_train, y_train, groups_train. no debes hacer es reutilizar outer_splits dentro del GridSearch, porque esos índices son del dataset completo, no de X_train.
                groups=groups_train,
                method="predict_proba",
                n_jobs=-1
            )[:, 1]

            fpr, tpr, thresholds = roc_curve(y_train, y_train_proba_oof)
            youden_index = tpr - fpr
            best_threshold = thresholds[np.argmax(youden_index)]

            thresholds_lr_youden.append(best_threshold)
            print ("Threshold: ", best_threshold)

            mdl_selected.fit(X_train, y_train)
            y_prob = mdl_selected.predict_proba(X_test)[:, 1]
            y_pred = (y_prob >= best_threshold).astype(int)
            
        elif model == "LogReg_Rho":
            y_train_proba_oof = cross_val_predict(mdl_selected, X_train, y_train, cv=cv_inner, groups=groups_train, method="predict_proba", n_jobs=-1)[:, 1]
            rho_threshold = get_best_rho(y_train,y_train_proba_oof, rhos=np.linspace(0.1, 0.9, 17))

            thresholds_lr_rho.append(rho_threshold)
            print ("Threshold: ", rho_threshold)

            mdl_selected.fit(X_train, y_train)
            y_prob = mdl_selected.predict_proba(X_test)[:, 1]
            y_pred = (y_prob >= rho_threshold).astype(int)
        else:
            mdl_selected.fit(X_train, y_train)
            y_pred = mdl_selected.predict(X_test)
            y_prob = mdl_selected.predict_proba(X_test)[:, 1]
        
        accuracy[i, j] = accuracy_score(y_test, y_pred)
        balanced_accuracy[i, j] = balanced_accuracy_score(y_test, y_pred)
        f1_macro[i, j] = f1_score(y_test, y_pred, average="macro")
        f1_weighted[i, j] = f1_score(y_test, y_pred, average="weighted")
        auc[i, j] = roc_auc_score(y_test, y_prob)

        cm = confusion_matrix(y_test, y_pred)

        print(f"\n===== Fold {j+1} - {model} - {grid.best_params_} =====")
        print(f"Accuracy: {accuracy[i,j]:.4f}")
        print(f"Balanced Accuracy: {balanced_accuracy[i,j]:.4f}")
        print(f"F1 Macro: {f1_macro[i,j]:.4f}")
        print(f"AUC: {auc[i,j]:.4f}")

        print("\nConfusion matrix:")
        print(cm)

        print("\nClassification report:")
        print(classification_report(y_test, y_pred))
        
for (i,model) in enumerate(models):
    accuracy_model.append(f"{np.mean(accuracy[i,:]):.2f} +- {np.std(accuracy[i,:]):.2f} [{np.min(accuracy[i,:]):.2f} -  {np.max(accuracy[i,:]):.2f}]")
    balanced_accuracy_model.append(f"{np.mean(balanced_accuracy[i,:]):.2f} +- {np.std(balanced_accuracy[i,:]):.2f} [{np.min(balanced_accuracy[i,:]):.2f} -  {np.max(balanced_accuracy[i,:]):.2f}]")
    f1_macro_model.append(f"{np.mean(f1_macro[i,:]):.2f} +- {np.std(f1_macro[i,:]):.2f}  [{np.min(f1_macro[i,:]):.2f}  -   {np.max(f1_macro[i,:]):.2f}]")
    f1_weighted_model.append(f"{np.mean(f1_weighted[i,:]):.2f} +- {np.std(f1_weighted[i,:]):.2f}  [{np.min(f1_weighted[i,:]):.2f}  -   {np.max(f1_weighted[i,:]):.2f}]")
    AUC_model.append(f"{np.mean(auc[i,:]):.2f} +- {np.std(auc[i,:]):.2f}  [ {np.min(auc[i,:]):.2f}  -  {np.max(auc[i,:]):.2f}]")
        
    if i == 0:
        type_response_df.append("cramps")
    else:
        type_response_df.append("")
        
    model_df.append(model)


df_performance_models = pd.DataFrame(np.transpose([type_response_df,model_df,accuracy_model,balanced_accuracy_model,f1_macro_model,f1_weighted_model, AUC_model]), columns=["Type response","Model", "Accuracy","Balanced Accuracy","F1-Score (macro)","F1-Score (weighted)","AUC"])
display(df_performance_models)
# Out:
# ['zscore__hr_mean', 'zscore__hr_min', 'zscore__hr_q_05', 'zscore__hr_q_25', 'ohe__phase_Menstrual']
#
# ===== Fold 1 - KNN - {'classifier__metric': 'euclidean', 'classifier__n_neighbors': 3, 'classifier__weights': 'distance', 'feature_selection__k': 5} =====
# Accuracy: 0.8739
# Balanced Accuracy: 0.5968
# F1 Macro: 0.5780
# AUC: 0.6545
#
# Confusion matrix:
# [[468  43]
#  [ 26  10]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.92      0.93       511
#            1       0.19      0.28      0.22        36
#
#     accuracy                           0.87       547
#    macro avg       0.57      0.60      0.58       547
# weighted avg       0.90      0.87      0.88       547
#
# ['zscore__hr_mean', 'zscore__hr_min', 'zscore__hr_q_05', 'zscore__hr_q_25', 'ohe__phase_Menstrual']
# Threshold:  0.4373511924817985
#
# ===== Fold 1 - LogReg_Youden - {'classifier__C': 1, 'classifier__class_weight': 'balanced', 'classifier__penalty': 'l1', 'feature_selection__k': 5} =====
# Accuracy: 0.7093
# Balanced Accuracy: 0.7024
# F1 Macro: 0.5298
# AUC: 0.7617
#
# Confusion matrix:
# [[363 148]
#  [ 11  25]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.71      0.82       511
#            1       0.14      0.69      0.24        36
#
#     accuracy                           0.71       547
#    macro avg       0.56      0.70      0.53       547
# weighted avg       0.92      0.71      0.78       547
#
# ['zscore__hr_mean', 'zscore__hr_min', 'zscore__hr_q_05', 'zscore__hr_q_25', 'ohe__phase_Menstrual']
# Threshold:  0.6
#
# ===== Fold 1 - LogReg_Rho - {'classifier__C': 1, 'classifier__class_weight': 'balanced', 'classifier__penalty': 'l1', 'feature_selection__k': 5} =====
# Accuracy: 0.8464
# Balanced Accuracy: 0.6983
# F1 Macro: 0.6125
# AUC: 0.7617
#
# Confusion matrix:
# [[444  67]
#  [ 17  19]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.87      0.91       511
#            1       0.22      0.53      0.31        36
#
#     accuracy                           0.85       547
#    macro avg       0.59      0.70      0.61       547
# weighted avg       0.91      0.85      0.87       547
#
#
# ===== Fold 1 - Random_Forest - {'classifier__class_weight': 'balanced', 'classifier__max_depth': 2, 'classifier__max_features': 'sqrt', 'classifier__max_leaf_nodes': 4, 'classifier__min_samples_leaf': 1, 'classifier__n_estimators': 10} =====
# Accuracy: 0.7367
# Balanced Accuracy: 0.7558
# F1 Macro: 0.5595
# AUC: 0.7782
#
# Confusion matrix:
# [[375 136]
#  [  8  28]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.73      0.84       511
#            1       0.17      0.78      0.28        36
#
#     accuracy                           0.74       547
#    macro avg       0.57      0.76      0.56       547
# weighted avg       0.93      0.74      0.80       547
#
# ['zscore__hr_mean', 'zscore__hr_min', 'zscore__hr_q_05', 'zscore__hr_q_25', 'ohe__phase_Menstrual']
#
# ===== Fold 1 - SVM - {'classifier__C': 1, 'classifier__class_weight': 'balanced', 'classifier__gamma': 'scale', 'classifier__kernel': 'linear', 'feature_selection__k': 5} =====
# Accuracy: 0.7587
# Balanced Accuracy: 0.7159
# F1 Macro: 0.5611
# AUC: 0.7772
#
# Confusion matrix:
# [[391 120]
#  [ 12  24]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.77      0.86       511
#            1       0.17      0.67      0.27        36
#
#     accuracy                           0.76       547
#    macro avg       0.57      0.72      0.56       547
# weighted avg       0.92      0.76      0.82       547
#
# ['zscore__hr_mean', 'zscore__hr_min', 'zscore__hr_q_05', 'zscore__hr_q_25', 'ohe__phase_Menstrual']
#
# ===== Fold 2 - KNN - {'classifier__metric': 'manhattan', 'classifier__n_neighbors': 7, 'classifier__weights': 'distance', 'feature_selection__k': 5} =====
# Accuracy: 0.8215
# Balanced Accuracy: 0.5729
# F1 Macro: 0.5812
# AUC: 0.6963
#
# Confusion matrix:
# [[469  41]
#  [ 65  19]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.92      0.90       510
#            1       0.32      0.23      0.26        84
#
#     accuracy                           0.82       594
#    macro avg       0.60      0.57      0.58       594
# weighted avg       0.80      0.82      0.81       594
#
# ['zscore__hr_mean', 'zscore__hr_median', 'zscore__hr_cv', 'zscore__hr_min', 'zscore__hr_q_05', 'zscore__hr_q_25', 'zscore__hr_q_75', 'zscore__glucose_mean', 'zscore__glucose_median', 'zscore__glucose_min', 'zscore__glucose_q_25', 'zscore__glucose_q_75', 'zscore__glucose_q_95', 'ohe__phase_Follicular', 'ohe__phase_Menstrual']
# Threshold:  0.36304044627958665
#
# ===== Fold 2 - LogReg_Youden - {'classifier__C': 1, 'classifier__class_weight': 'balanced', 'classifier__penalty': 'l2', 'feature_selection__k': 15} =====
# Accuracy: 0.7189
# Balanced Accuracy: 0.7468
# F1 Macro: 0.6268
# AUC: 0.7798
#
# Confusion matrix:
# [[361 149]
#  [ 18  66]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.71      0.81       510
#            1       0.31      0.79      0.44        84
#
#     accuracy                           0.72       594
#    macro avg       0.63      0.75      0.63       594
# weighted avg       0.86      0.72      0.76       594
#
# ['zscore__hr_mean', 'zscore__hr_median', 'zscore__hr_cv', 'zscore__hr_min', 'zscore__hr_q_05', 'zscore__hr_q_25', 'zscore__hr_q_75', 'zscore__glucose_mean', 'zscore__glucose_median', 'zscore__glucose_min', 'zscore__glucose_q_25', 'zscore__glucose_q_75', 'zscore__glucose_q_95', 'ohe__phase_Follicular', 'ohe__phase_Menstrual']
# Threshold:  0.55
#
# ===== Fold 2 - LogReg_Rho - {'classifier__C': 1, 'classifier__class_weight': 'balanced', 'classifier__penalty': 'l2', 'feature_selection__k': 15} =====
# Accuracy: 0.7912
# Balanced Accuracy: 0.6994
# F1 Macro: 0.6541
# AUC: 0.7798
#
# Confusion matrix:
# [[422  88]
#  [ 36  48]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.83      0.87       510
#            1       0.35      0.57      0.44        84
#
#     accuracy                           0.79       594
#    macro avg       0.64      0.70      0.65       594
# weighted avg       0.84      0.79      0.81       594
#
#
# ===== Fold 2 - Random_Forest - {'classifier__class_weight': 'balanced', 'classifier__max_depth': 3, 'classifier__max_features': 'sqrt', 'classifier__max_leaf_nodes': 8, 'classifier__min_samples_leaf': 10, 'classifier__n_estimators': 10} =====
# Accuracy: 0.7811
# Balanced Accuracy: 0.7085
# F1 Macro: 0.6518
# AUC: 0.7516
#
# Confusion matrix:
# [[413  97]
#  [ 33  51]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.81      0.86       510
#            1       0.34      0.61      0.44        84
#
#     accuracy                           0.78       594
#    macro avg       0.64      0.71      0.65       594
# weighted avg       0.84      0.78      0.80       594
#
# ['zscore__hr_mean', 'zscore__hr_min', 'zscore__hr_q_05', 'zscore__hr_q_25', 'ohe__phase_Menstrual']
#
# ===== Fold 2 - SVM - {'classifier__C': 10, 'classifier__class_weight': 'balanced', 'classifier__gamma': 'scale', 'classifier__kernel': 'rbf', 'feature_selection__k': 5} =====
# Accuracy: 0.7896
# Balanced Accuracy: 0.7382
# F1 Macro: 0.6706
# AUC: 0.7880
#
# Confusion matrix:
# [[413  97]
#  [ 28  56]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.94      0.81      0.87       510
#            1       0.37      0.67      0.47        84
#
#     accuracy                           0.79       594
#    macro avg       0.65      0.74      0.67       594
# weighted avg       0.86      0.79      0.81       594
#
# ['zscore__hr_mean', 'zscore__hr_min', 'zscore__hr_q_05', 'zscore__hr_q_25', 'ohe__phase_Menstrual']
#
# ===== Fold 3 - KNN - {'classifier__metric': 'euclidean', 'classifier__n_neighbors': 3, 'classifier__weights': 'uniform', 'feature_selection__k': 5} =====
# Accuracy: 0.7588
# Balanced Accuracy: 0.5240
# F1 Macro: 0.5112
# AUC: 0.6081
#
# Confusion matrix:
# [[250  16]
#  [ 66   8]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.79      0.94      0.86       266
#            1       0.33      0.11      0.16        74
#
#     accuracy                           0.76       340
#    macro avg       0.56      0.52      0.51       340
# weighted avg       0.69      0.76      0.71       340
#
# ['zscore__hr_mean', 'zscore__hr_cv', 'zscore__hr_min', 'zscore__hr_q_05', 'zscore__hr_q_25', 'zscore__glucose_mean', 'zscore__glucose_median', 'zscore__glucose_q_75', 'ohe__phase_Follicular', 'ohe__phase_Menstrual']
# Threshold:  0.4551305961802974
#
# ===== Fold 3 - LogReg_Youden - {'classifier__C': 1, 'classifier__class_weight': 'balanced', 'classifier__penalty': 'l2', 'feature_selection__k': 10} =====
# Accuracy: 0.7118
# Balanced Accuracy: 0.6207
# F1 Macro: 0.6095
# AUC: 0.6904
#
# Confusion matrix:
# [[208  58]
#  [ 40  34]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.78      0.81       266
#            1       0.37      0.46      0.41        74
#
#     accuracy                           0.71       340
#    macro avg       0.60      0.62      0.61       340
# weighted avg       0.74      0.71      0.72       340
#
# ['zscore__hr_mean', 'zscore__hr_cv', 'zscore__hr_min', 'zscore__hr_q_05', 'zscore__hr_q_25', 'zscore__glucose_mean', 'zscore__glucose_median', 'zscore__glucose_q_75', 'ohe__phase_Follicular', 'ohe__phase_Menstrual']
# Threshold:  0.5
#
# ===== Fold 3 - LogReg_Rho - {'classifier__C': 1, 'classifier__class_weight': 'balanced', 'classifier__penalty': 'l2', 'feature_selection__k': 10} =====
# Accuracy: 0.7382
# Balanced Accuracy: 0.6327
# F1 Macro: 0.6281
# AUC: 0.6904
#
# Confusion matrix:
# [[218  48]
#  [ 41  33]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.82      0.83       266
#            1       0.41      0.45      0.43        74
#
#     accuracy                           0.74       340
#    macro avg       0.62      0.63      0.63       340
# weighted avg       0.75      0.74      0.74       340
#
#
# ===== Fold 3 - Random_Forest - {'classifier__class_weight': 'balanced', 'classifier__max_depth': 7, 'classifier__max_features': 'sqrt', 'classifier__max_leaf_nodes': 16, 'classifier__min_samples_leaf': 1, 'classifier__n_estimators': 10} =====
# Accuracy: 0.7265
# Balanced Accuracy: 0.5911
# F1 Macro: 0.5924
# AUC: 0.6360
#
# Confusion matrix:
# [[221  45]
#  [ 48  26]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.82      0.83      0.83       266
#            1       0.37      0.35      0.36        74
#
#     accuracy                           0.73       340
#    macro avg       0.59      0.59      0.59       340
# weighted avg       0.72      0.73      0.72       340
#
# ['zscore__hr_mean', 'zscore__hr_cv', 'zscore__hr_min', 'zscore__hr_q_05', 'zscore__hr_q_25', 'zscore__glucose_mean', 'zscore__glucose_median', 'zscore__glucose_q_75', 'ohe__phase_Follicular', 'ohe__phase_Menstrual']
#
# ===== Fold 3 - SVM - {'classifier__C': 1, 'classifier__class_weight': 'balanced', 'classifier__gamma': 'scale', 'classifier__kernel': 'rbf', 'feature_selection__k': 10} =====
# Accuracy: 0.7147
# Balanced Accuracy: 0.6275
# F1 Macro: 0.6150
# AUC: 0.6844
#
# Confusion matrix:
# [[208  58]
#  [ 39  35]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.78      0.81       266
#            1       0.38      0.47      0.42        74
#
#     accuracy                           0.71       340
#    macro avg       0.61      0.63      0.62       340
# weighted avg       0.74      0.71      0.73       340
#
# ['zscore__hr_mean', 'zscore__hr_min', 'zscore__hr_q_05', 'zscore__hr_q_25', 'ohe__phase_Menstrual']
#
# ===== Fold 4 - KNN - {'classifier__metric': 'euclidean', 'classifier__n_neighbors': 3, 'classifier__weights': 'distance', 'feature_selection__k': 5} =====
# Accuracy: 0.8008
# Balanced Accuracy: 0.5765
# F1 Macro: 0.5720
# AUC: 0.6339
#
# Confusion matrix:
# [[396  56]
#  [ 47  18]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.88      0.88       452
#            1       0.24      0.28      0.26        65
#
#     accuracy                           0.80       517
#    macro avg       0.57      0.58      0.57       517
# weighted avg       0.81      0.80      0.81       517
#
# ['zscore__hr_mean', 'zscore__hr_median', 'zscore__hr_cv', 'zscore__hr_min', 'zscore__hr_q_05', 'zscore__hr_q_25', 'zscore__hr_q_75', 'zscore__glucose_q_75', 'ohe__phase_Follicular', 'ohe__phase_Menstrual']
# Threshold:  0.4349964998579788
#
# ===== Fold 4 - LogReg_Youden - {'classifier__C': 1, 'classifier__class_weight': 'balanced', 'classifier__penalty': 'l1', 'feature_selection__k': 10} =====
# Accuracy: 0.6673
# Balanced Accuracy: 0.7175
# F1 Macro: 0.5730
# AUC: 0.7502
#
# Confusion matrix:
# [[294 158]
#  [ 14  51]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.65      0.77       452
#            1       0.24      0.78      0.37        65
#
#     accuracy                           0.67       517
#    macro avg       0.60      0.72      0.57       517
# weighted avg       0.87      0.67      0.72       517
#
# ['zscore__hr_mean', 'zscore__hr_median', 'zscore__hr_cv', 'zscore__hr_min', 'zscore__hr_q_05', 'zscore__hr_q_25', 'zscore__hr_q_75', 'zscore__glucose_q_75', 'ohe__phase_Follicular', 'ohe__phase_Menstrual']
# Threshold:  0.65
#
# ===== Fold 4 - LogReg_Rho - {'classifier__C': 1, 'classifier__class_weight': 'balanced', 'classifier__penalty': 'l1', 'feature_selection__k': 10} =====
# Accuracy: 0.7834
# Balanced Accuracy: 0.6785
# F1 Macro: 0.6266
# AUC: 0.7502
#
# Confusion matrix:
# [[370  82]
#  [ 30  35]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.82      0.87       452
#            1       0.30      0.54      0.38        65
#
#     accuracy                           0.78       517
#    macro avg       0.61      0.68      0.63       517
# weighted avg       0.85      0.78      0.81       517
#
#
# ===== Fold 4 - Random_Forest - {'classifier__class_weight': 'balanced', 'classifier__max_depth': 10, 'classifier__max_features': 'log2', 'classifier__max_leaf_nodes': 32, 'classifier__min_samples_leaf': 10, 'classifier__n_estimators': 20} =====
# Accuracy: 0.7369
# Balanced Accuracy: 0.6059
# F1 Macro: 0.5651
# AUC: 0.6927
#
# Confusion matrix:
# [[353  99]
#  [ 37  28]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.78      0.84       452
#            1       0.22      0.43      0.29        65
#
#     accuracy                           0.74       517
#    macro avg       0.56      0.61      0.57       517
# weighted avg       0.82      0.74      0.77       517
#
# ['zscore__hr_mean', 'zscore__hr_median', 'zscore__hr_cv', 'zscore__hr_min', 'zscore__hr_q_05', 'zscore__hr_q_25', 'zscore__hr_q_75', 'zscore__glucose_q_75', 'ohe__phase_Follicular', 'ohe__phase_Menstrual']
#
# ===== Fold 4 - SVM - {'classifier__C': 1, 'classifier__class_weight': 'balanced', 'classifier__gamma': 'scale', 'classifier__kernel': 'linear', 'feature_selection__k': 10} =====
# Accuracy: 0.7157
# Balanced Accuracy: 0.7254
# F1 Macro: 0.6046
# AUC: 0.7548
#
# Confusion matrix:
# [[322 130]
#  [ 17  48]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.71      0.81       452
#            1       0.27      0.74      0.40        65
#
#     accuracy                           0.72       517
#    macro avg       0.61      0.73      0.60       517
# weighted avg       0.86      0.72      0.76       517
#
# ['zscore__hr_min', 'zscore__hr_q_05', 'ohe__phase_Fertility', 'ohe__phase_Follicular', 'ohe__phase_Menstrual']
#
# ===== Fold 5 - KNN - {'classifier__metric': 'euclidean', 'classifier__n_neighbors': 3, 'classifier__weights': 'uniform', 'feature_selection__k': 5} =====
# Accuracy: 0.7094
# Balanced Accuracy: 0.5333
# F1 Macro: 0.5172
# AUC: 0.5992
#
# Confusion matrix:
# [[376  31]
#  [132  22]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.74      0.92      0.82       407
#            1       0.42      0.14      0.21       154
#
#     accuracy                           0.71       561
#    macro avg       0.58      0.53      0.52       561
# weighted avg       0.65      0.71      0.65       561
#
# ['zscore__hr_min', 'zscore__hr_q_05', 'ohe__phase_Fertility', 'ohe__phase_Follicular', 'ohe__phase_Menstrual']
# Threshold:  0.5121132954048458
#
# ===== Fold 5 - LogReg_Youden - {'classifier__C': 0.01, 'classifier__class_weight': 'balanced', 'classifier__penalty': 'l1', 'feature_selection__k': 5} =====
# Accuracy: 0.7326
# Balanced Accuracy: 0.6623
# F1 Macro: 0.6630
# AUC: 0.8004
#
# Confusion matrix:
# [[333  74]
#  [ 76  78]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.81      0.82      0.82       407
#            1       0.51      0.51      0.51       154
#
#     accuracy                           0.73       561
#    macro avg       0.66      0.66      0.66       561
# weighted avg       0.73      0.73      0.73       561
#
# ['zscore__hr_min', 'zscore__hr_q_05', 'ohe__phase_Fertility', 'ohe__phase_Follicular', 'ohe__phase_Menstrual']
# Threshold:  0.5
#
# ===== Fold 5 - LogReg_Rho - {'classifier__C': 0.01, 'classifier__class_weight': 'balanced', 'classifier__penalty': 'l1', 'feature_selection__k': 5} =====
# Accuracy: 0.7540
# Balanced Accuracy: 0.7154
# F1 Macro: 0.7048
# AUC: 0.8004
#
# Confusion matrix:
# [[326  81]
#  [ 57  97]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.80      0.83       407
#            1       0.54      0.63      0.58       154
#
#     accuracy                           0.75       561
#    macro avg       0.70      0.72      0.70       561
# weighted avg       0.77      0.75      0.76       561
#
#
# ===== Fold 5 - Random_Forest - {'classifier__class_weight': 'balanced', 'classifier__max_depth': 1, 'classifier__max_features': 'sqrt', 'classifier__max_leaf_nodes': 2, 'classifier__min_samples_leaf': 1, 'classifier__n_estimators': 10} =====
# Accuracy: 0.6720
# Balanced Accuracy: 0.5802
# F1 Macro: 0.5814
# AUC: 0.6662
#
# Confusion matrix:
# [[319  88]
#  [ 96  58]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.77      0.78      0.78       407
#            1       0.40      0.38      0.39       154
#
#     accuracy                           0.67       561
#    macro avg       0.58      0.58      0.58       561
# weighted avg       0.67      0.67      0.67       561
#
# ['zscore__hr_min', 'zscore__hr_q_05', 'ohe__phase_Fertility', 'ohe__phase_Follicular', 'ohe__phase_Menstrual']
#
# ===== Fold 5 - SVM - {'classifier__C': 0.1, 'classifier__class_weight': 'balanced', 'classifier__gamma': 'scale', 'classifier__kernel': 'linear', 'feature_selection__k': 5} =====
# Accuracy: 0.6827
# Balanced Accuracy: 0.5492
# F1 Macro: 0.5496
# AUC: 0.6674
#
# Confusion matrix:
# [[344  63]
#  [115  39]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.75      0.85      0.79       407
#            1       0.38      0.25      0.30       154
#
#     accuracy                           0.68       561
#    macro avg       0.57      0.55      0.55       561
# weighted avg       0.65      0.68      0.66       561
#   Type response          Model                     Accuracy  \
# 0        cramps            KNN  0.79 +- 0.06 [0.71 -  0.87]
# 1                LogReg_Youden  0.71 +- 0.02 [0.67 -  0.73]
# 2                   LogReg_Rho  0.78 +- 0.04 [0.74 -  0.85]
# 3                Random_Forest  0.73 +- 0.03 [0.67 -  0.78]
# 4                          SVM  0.73 +- 0.04 [0.68 -  0.79]
#
#              Balanced Accuracy                F1-Score (macro)  \
# 0  0.56 +- 0.03 [0.52 -  0.60]  0.55 +- 0.03  [0.51  -   0.58]
# 1  0.69 +- 0.04 [0.62 -  0.75]  0.60 +- 0.05  [0.53  -   0.66]
# 2  0.68 +- 0.03 [0.63 -  0.72]  0.65 +- 0.03  [0.61  -   0.70]
# 3  0.65 +- 0.07 [0.58 -  0.76]  0.59 +- 0.03  [0.56  -   0.65]
# 4  0.67 +- 0.07 [0.55 -  0.74]  0.60 +- 0.04  [0.55  -   0.67]
#
#               F1-Score (weighted)                             AUC
# 0  0.77 +- 0.08  [0.65  -   0.88]  0.64 +- 0.03  [ 0.60  -  0.70]
# 1  0.74 +- 0.02  [0.72  -   0.78]  0.76 +- 0.04  [ 0.69  -  0.80]
# 2  0.80 +- 0.05  [0.74  -   0.87]  0.76 +- 0.04  [ 0.69  -  0.80]
# 3  0.75 +- 0.05  [0.67  -   0.80]  0.70 +- 0.05  [ 0.64  -  0.78]
# 4  0.76 +- 0.06  [0.66  -   0.82]  0.73 +- 0.05  [ 0.67  -  0.79]
