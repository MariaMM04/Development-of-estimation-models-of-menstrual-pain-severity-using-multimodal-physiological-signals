# %%
from sklearn import svm

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as stats
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler as  StandardScaler
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, classification_report, balanced_accuracy_score
from sklearn.model_selection import KFold, cross_validate, cross_val_score, GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.model_selection import StratifiedKFold
from sklearn.feature_selection import SelectKBest, f_classif, SelectFromModel
from imblearn.pipeline import Pipeline as im_Pipeline

from sklearn.model_selection import StratifiedGroupKFold, cross_val_predict
from sklearn.metrics import roc_curve, confusion_matrix

from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler

# %%
df1 = pd.read_csv("master_tripel_cramps_dataset.csv")

df_ogmenstrual = df1[df1["phase"] == "Menstrual"].copy()

df_clean_menstrual_og = df_ogmenstrual.dropna(subset=[
    "cramps",
    "cramps binary",
    "cramps group",
    "phase",
    "lh",
    "estrogen",
    "nightly_temperature",
    "hr_mean",
    "glucose_median",
    "glucose_std"
]).copy()

cramps_map_menstrual = {
    "Not at all": 0,
    "Very Low/Little": 1,
    "Low": 2,
    "Moderate": 3,
    "High": 4,
    "Very High": 5
}

cramps_map_binary_menstrual = {
    "Low Pain": 0,
    "High Pain": 1,
}

cramps_map_group_menstrual = {
    "No Pain": 0,
    "Low Pain": 1,
    "High Pain": 2,
}

df_clean_menstrual_og["cramps"] = df_clean_menstrual_og["cramps"].map(cramps_map_menstrual)
df_clean_menstrual_og["cramps binary"] = df_clean_menstrual_og["cramps binary"].map(cramps_map_binary_menstrual)
df_clean_menstrual_og["cramps group"] = df_clean_menstrual_og["cramps group"].map(cramps_map_group_menstrual)

df_clean_menstrual_og = df_clean_menstrual_og.dropna(subset=["cramps binary"]).copy()
drop_cols = [
    "id",
    "phase",
    "cramps",
    "cramps binary",
    "cramps group",
    "study_interval_x",
    "study_interval_y",
    "day_in_study"
]

X = df_clean_menstrual_og.drop(columns=drop_cols)
y = df_clean_menstrual_og["cramps binary"].astype(int)

variables_num = X.columns.tolist()

# %%
groups = df_clean_menstrual_og["id"]

cv_outer = StratifiedGroupKFold(
    n_splits=5,
    shuffle=True,
    random_state=42
)

cv_inner = StratifiedGroupKFold(
    n_splits=5,
    shuffle=True,
    random_state=42
)

import pickle 
with open("outer_splits_menstrual_binary.pkl", "rb") as f:
    outer_splits = pickle.load(f)

def get_best_rho(y_train, y_train_proba_oof, rhos=np.linspace(0.1, 0.9, 17)):

    best_rho = None
    best_f1 = -1

    for rho in rhos:

        y_pred = (y_train_proba_oof >= rho).astype(int)

        f1 = f1_score(y_train, y_pred, average="macro")

        if f1 > best_f1:
            best_f1 = f1
            best_rho = rho

    return best_rho

# %%
param_grid = {"KNN": {
                    "classifier__n_neighbors": [3, 5, 7, 9, 11],
                    "classifier__weights": ["uniform", "distance"],
                    "classifier__metric": ["euclidean", "manhattan"],
                    "feature_selection__k": [5, 10, 15, 20, "all"]}, 
              "LogReg_Youden": {
                    "classifier__C": [0.001, 0.01, 0.1, 1, 10],
                    "classifier__class_weight": ["balanced"],
                    "classifier__penalty": ["l1", "l2"],
                    "feature_selection__k": [5, 10, 15, 20, "all"]},
              "LogReg_Rho": {
                    "classifier__C": [0.001, 0.01, 0.1, 1, 10],
                    "classifier__class_weight": ["balanced"],
                    "classifier__penalty": ["l1", "l2"],
                    "feature_selection__k": [5, 10, 15, 20, "all"]},
              "Random_Forest": {
                    "classifier__n_estimators": [10, 20, 50, 100, 200, 250, 300, 500],
                    "classifier__max_depth": [1, 2, 3, 5, 7, 10],
                    "classifier__min_samples_leaf": [1, 5, 10],
                    "classifier__max_features": ["sqrt", "log2"],
                    "classifier__max_leaf_nodes": [2, 4, 8, 16, 32],
                    "classifier__class_weight": ["balanced"]},
              "SVM":{
                    "classifier__kernel": ["linear","rbf"],
                    "classifier__gamma": ["scale", "auto"],
                    "classifier__C": [0.01, 0.1, 1, 10],
                    "classifier__class_weight": ["balanced"],
                    "feature_selection__k": [5, 10, 15, 20, "all"]}

    }

# %%
model_df = []
type_response_df = []
accuracy_model = []
balanced_accuracy_model = []
f1_macro_model = []
f1_weighted_model = []
AUC_model = []
models = ["KNN", "LogReg_Youden", "LogReg_Rho","Random_Forest","SVM"]


accuracy = np.nan * np.ones((len(models), len(outer_splits)))
balanced_accuracy = np.nan * np.ones((len(models), len(outer_splits)))
f1_macro = np.nan * np.ones((len(models), len(outer_splits)))
f1_weighted = np.nan * np.ones((len(models), len(outer_splits)))
auc = np.nan * np.ones((len(models), len(outer_splits)))

best_params_all = {model: [] for model in models}
selected_features_all = {model: [] for model in models}
thresholds_lr_youden = []
thresholds_lr_rho = []

for j, (train_idx, test_idx) in enumerate(outer_splits):
    X_train = X.iloc[train_idx]
    X_test = X.iloc[test_idx]

    y_train = y.iloc[train_idx]
    y_test = y.iloc[test_idx]

    groups_train = groups.iloc[train_idx]
        
    for (i,model) in enumerate(models):
        preprocessor = ColumnTransformer(
            transformers=[
                ("zscore", StandardScaler(), variables_num)
        ])
        match model:
            case "LogReg_Youden":
                mdl = LogisticRegression( solver = "saga", max_iter=1000, random_state = 42)
            case "LogReg_Rho":
                mdl = LogisticRegression( solver = "saga", max_iter=1000, random_state = 42)    
            case "Random_Forest":
                mdl = RandomForestClassifier(random_state = 42)
            case "KNN":
                mdl = KNeighborsClassifier()
            case "SVM":
                mdl = svm.SVC(probability = True, random_state = 42)
        if model == "Random_Forest":
            pipeline = im_Pipeline([
                ("preprocessor", preprocessor),
                ("smote", SMOTE(sampling_strategy=0.9,random_state=42)),
                ("undersample", RandomUnderSampler(sampling_strategy=1.0,random_state=42)),
                ("classifier", mdl)])
        else:
            pipeline = im_Pipeline([
                ("preprocessor", preprocessor),
                ("smote", SMOTE(sampling_strategy=0.9,random_state=42)),
                ("undersample", RandomUnderSampler(sampling_strategy=1.0,random_state=42)),
                ("feature_selection", SelectKBest(score_func=f_classif)),
                ("classifier", mdl)])

        grid = GridSearchCV(
                estimator=pipeline,
                param_grid=param_grid[model],
                cv=cv_inner,
                scoring="f1_macro",
                n_jobs=-1)
        
        grid.fit(X_train, y_train, groups=groups_train)
        
        mdl_selected = grid.best_estimator_
        best_params_all[model].append(grid.best_params_)
        
        if model != "Random_Forest":
            selector = mdl_selected.named_steps["feature_selection"]
            selected_features = X_train.columns[selector.get_support()].tolist()
            print(selected_features)
        else:
            selected_features = X_train.columns.tolist()

        selected_features_all[model].append(selected_features)

        if model == "LogReg_Youden":
            y_train_proba_oof = cross_val_predict(
                mdl_selected,
                X_train,
                y_train,
                cv=cv_inner,   # cv_outer, pero aplicado a X_train, y_train, groups_train. no debes hacer es reutilizar outer_splits dentro del GridSearch, porque esos índices son del dataset completo, no de X_train.
                groups=groups_train,
                method="predict_proba",
                n_jobs=-1
            )[:, 1]

            fpr, tpr, thresholds = roc_curve(y_train, y_train_proba_oof)
            youden_index = tpr - fpr
            best_threshold = thresholds[np.argmax(youden_index)]

            thresholds_lr_youden.append(best_threshold)
            print("Threshold: ", best_threshold)

            mdl_selected.fit(X_train, y_train)
            y_prob = mdl_selected.predict_proba(X_test)[:, 1]
            y_pred = (y_prob >= best_threshold).astype(int)
            
        elif model == "LogReg_Rho":
            y_train_proba_oof = cross_val_predict(mdl_selected, X_train, y_train, cv=cv_inner, groups=groups_train, method="predict_proba", n_jobs=-1)[:, 1]
            rho_threshold = get_best_rho(y_train,y_train_proba_oof, rhos=np.linspace(0.1, 0.9, 17))

            thresholds_lr_rho.append(rho_threshold)
            print("Threshold: ", rho_threshold)

            mdl_selected.fit(X_train, y_train)
            y_prob = mdl_selected.predict_proba(X_test)[:, 1]
            y_pred = (y_prob >= rho_threshold).astype(int)
        else:
            mdl_selected.fit(X_train, y_train)
            y_pred = mdl_selected.predict(X_test)
            y_prob = mdl_selected.predict_proba(X_test)[:, 1]
        
        accuracy[i, j] = accuracy_score(y_test, y_pred)
        balanced_accuracy[i, j] = balanced_accuracy_score(y_test, y_pred)
        f1_macro[i, j] = f1_score(y_test, y_pred, average="macro")
        f1_weighted[i, j] = f1_score(y_test, y_pred, average="weighted")
        auc[i, j] = roc_auc_score(y_test, y_prob)

        cm = confusion_matrix(y_test, y_pred)

        print(f"\n===== Fold {j+1} - {model} - {grid.best_params_} =====")
        print(f"Accuracy: {accuracy[i,j]:.4f}")
        print(f"Balanced Accuracy: {balanced_accuracy[i,j]:.4f}")
        print(f"F1 Macro: {f1_macro[i,j]:.4f}")
        print(f"AUC: {auc[i,j]:.4f}")

        print("\nConfusion matrix:")
        print(cm)

        print("\nClassification report:")
        print(classification_report(y_test, y_pred))
        
for (i,model) in enumerate(models):
    accuracy_model.append(f"{np.mean(accuracy[i,:]):.2f} +- {np.std(accuracy[i,:]):.2f} [{np.min(accuracy[i,:]):.2f} -  {np.max(accuracy[i,:]):.2f}]")
    balanced_accuracy_model.append(f"{np.mean(balanced_accuracy[i,:]):.2f} +- {np.std(balanced_accuracy[i,:]):.2f} [{np.min(balanced_accuracy[i,:]):.2f} -  {np.max(balanced_accuracy[i,:]):.2f}]")
    f1_macro_model.append(f"{np.mean(f1_macro[i,:]):.2f} +- {np.std(f1_macro[i,:]):.2f}  [{np.min(f1_macro[i,:]):.2f}  -   {np.max(f1_macro[i,:]):.2f}]")
    f1_weighted_model.append(f"{np.mean(f1_weighted[i,:]):.2f} +- {np.std(f1_weighted[i,:]):.2f}  [{np.min(f1_weighted[i,:]):.2f}  -   {np.max(f1_weighted[i,:]):.2f}]")
    AUC_model.append(f"{np.mean(auc[i,:]):.2f} +- {np.std(auc[i,:]):.2f}  [ {np.min(auc[i,:]):.2f}  -  {np.max(auc[i,:]):.2f}]")
        
    if i == 0:
        type_response_df.append("cramps")
    else:
        type_response_df.append("")
        
    model_df.append(model)


df_performance_models = pd.DataFrame(np.transpose([type_response_df,model_df,accuracy_model,balanced_accuracy_model,f1_macro_model,f1_weighted_model, AUC_model]), columns=["Type response","Model", "Accuracy","Balanced Accuracy","F1-Score (macro)","F1-Score (weighted)","AUC"])
display(df_performance_models)
# Out:
# ['lh', 'hr_mean', 'hr_median', 'hr_min', 'hr_q_05', 'hr_q_25', 'hr_q_75', 'glucose_mean', 'glucose_median', 'glucose_min', 'glucose_max', 'glucose_q_05', 'glucose_q_25', 'glucose_q_75', 'glucose_q_95']
#
# ===== Fold 1 - KNN - {'classifier__metric': 'manhattan', 'classifier__n_neighbors': 9, 'classifier__weights': 'uniform', 'feature_selection__k': 15} =====
# Accuracy: 0.6283
# Balanced Accuracy: 0.6235
# F1 Macro: 0.6197
# AUC: 0.6335
#
# Confusion matrix:
# [[44 24]
#  [18 27]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.71      0.65      0.68        68
#            1       0.53      0.60      0.56        45
#
#     accuracy                           0.63       113
#    macro avg       0.62      0.62      0.62       113
# weighted avg       0.64      0.63      0.63       113
#
# ['lh', 'hr_mean', 'hr_median', 'hr_min', 'hr_q_05', 'hr_q_25', 'hr_q_75', 'glucose_mean', 'glucose_median', 'glucose_min', 'glucose_max', 'glucose_q_05', 'glucose_q_25', 'glucose_q_75', 'glucose_q_95']
# Threshold:  0.515119845661262
#
# ===== Fold 1 - LogReg_Youden - {'classifier__C': 0.01, 'classifier__class_weight': 'balanced', 'classifier__penalty': 'l2', 'feature_selection__k': 15} =====
# Accuracy: 0.6726
# Balanced Accuracy: 0.6565
# F1 Macro: 0.6571
# AUC: 0.6510
#
# Confusion matrix:
# [[50 18]
#  [19 26]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.72      0.74      0.73        68
#            1       0.59      0.58      0.58        45
#
#     accuracy                           0.67       113
#    macro avg       0.66      0.66      0.66       113
# weighted avg       0.67      0.67      0.67       113
#
# ['lh', 'hr_mean', 'hr_median', 'hr_min', 'hr_q_05', 'hr_q_25', 'hr_q_75', 'glucose_mean', 'glucose_median', 'glucose_min', 'glucose_max', 'glucose_q_05', 'glucose_q_25', 'glucose_q_75', 'glucose_q_95']
# Threshold:  0.5
#
# ===== Fold 1 - LogReg_Rho - {'classifier__C': 0.01, 'classifier__class_weight': 'balanced', 'classifier__penalty': 'l2', 'feature_selection__k': 15} =====
# Accuracy: 0.6372
# Balanced Accuracy: 0.6271
# F1 Macro: 0.6254
# AUC: 0.6510
#
# Confusion matrix:
# [[46 22]
#  [19 26]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.71      0.68      0.69        68
#            1       0.54      0.58      0.56        45
#
#     accuracy                           0.64       113
#    macro avg       0.62      0.63      0.63       113
# weighted avg       0.64      0.64      0.64       113
#
#
# ===== Fold 1 - Random_Forest - {'classifier__class_weight': 'balanced', 'classifier__max_depth': 10, 'classifier__max_features': 'log2', 'classifier__max_leaf_nodes': 32, 'classifier__min_samples_leaf': 1, 'classifier__n_estimators': 10} =====
# Accuracy: 0.6106
# Balanced Accuracy: 0.6013
# F1 Macro: 0.5993
# AUC: 0.6069
#
# Confusion matrix:
# [[44 24]
#  [20 25]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.69      0.65      0.67        68
#            1       0.51      0.56      0.53        45
#
#     accuracy                           0.61       113
#    macro avg       0.60      0.60      0.60       113
# weighted avg       0.62      0.61      0.61       113
#
# ['lh', 'hr_mean', 'hr_median', 'hr_min', 'hr_q_05', 'hr_q_25', 'hr_q_75', 'glucose_mean', 'glucose_median', 'glucose_min', 'glucose_max', 'glucose_q_05', 'glucose_q_25', 'glucose_q_75', 'glucose_q_95']
#
# ===== Fold 1 - SVM - {'classifier__C': 0.01, 'classifier__class_weight': 'balanced', 'classifier__gamma': 'scale', 'classifier__kernel': 'linear', 'feature_selection__k': 15} =====
# Accuracy: 0.6460
# Balanced Accuracy: 0.6345
# F1 Macro: 0.6334
# AUC: 0.6549
#
# Confusion matrix:
# [[47 21]
#  [19 26]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.71      0.69      0.70        68
#            1       0.55      0.58      0.57        45
#
#     accuracy                           0.65       113
#    macro avg       0.63      0.63      0.63       113
# weighted avg       0.65      0.65      0.65       113
#
# ['lh', 'hr_mean', 'hr_median', 'hr_min', 'hr_q_05', 'hr_q_25', 'hr_q_75', 'glucose_mean', 'glucose_median', 'glucose_min', 'glucose_max', 'glucose_q_05', 'glucose_q_25', 'glucose_q_75', 'glucose_q_95']
#
# ===== Fold 2 - KNN - {'classifier__metric': 'manhattan', 'classifier__n_neighbors': 11, 'classifier__weights': 'distance', 'feature_selection__k': 15} =====
# Accuracy: 0.6857
# Balanced Accuracy: 0.6339
# F1 Macro: 0.6354
# AUC: 0.5245
#
# Confusion matrix:
# [[37  6]
#  [16 11]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.70      0.86      0.77        43
#            1       0.65      0.41      0.50        27
#
#     accuracy                           0.69        70
#    macro avg       0.67      0.63      0.64        70
# weighted avg       0.68      0.69      0.67        70
#
# ['lh', 'estrogen', 'hr_mean', 'hr_median', 'hr_cv', 'hr_min', 'hr_q_05', 'hr_q_25', 'hr_q_75', 'hr_q_95', 'glucose_mean', 'glucose_median', 'glucose_std', 'glucose_var', 'glucose_min', 'glucose_max', 'glucose_q_05', 'glucose_q_25', 'glucose_q_75', 'glucose_q_95']
# Threshold:  0.46698475842329484
#
# ===== Fold 2 - LogReg_Youden - {'classifier__C': 0.1, 'classifier__class_weight': 'balanced', 'classifier__penalty': 'l2', 'feature_selection__k': 20} =====
# Accuracy: 0.5000
# Balanced Accuracy: 0.4759
# F1 Macro: 0.4759
# AUC: 0.5375
#
# Confusion matrix:
# [[25 18]
#  [17 10]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.60      0.58      0.59        43
#            1       0.36      0.37      0.36        27
#
#     accuracy                           0.50        70
#    macro avg       0.48      0.48      0.48        70
# weighted avg       0.50      0.50      0.50        70
#
# ['lh', 'estrogen', 'hr_mean', 'hr_median', 'hr_cv', 'hr_min', 'hr_q_05', 'hr_q_25', 'hr_q_75', 'hr_q_95', 'glucose_mean', 'glucose_median', 'glucose_std', 'glucose_var', 'glucose_min', 'glucose_max', 'glucose_q_05', 'glucose_q_25', 'glucose_q_75', 'glucose_q_95']
# Threshold:  0.5
#
# ===== Fold 2 - LogReg_Rho - {'classifier__C': 0.1, 'classifier__class_weight': 'balanced', 'classifier__penalty': 'l2', 'feature_selection__k': 20} =====
# Accuracy: 0.5286
# Balanced Accuracy: 0.4991
# F1 Macro: 0.4990
# AUC: 0.5375
#
# Confusion matrix:
# [[27 16]
#  [17 10]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.61      0.63      0.62        43
#            1       0.38      0.37      0.38        27
#
#     accuracy                           0.53        70
#    macro avg       0.50      0.50      0.50        70
# weighted avg       0.53      0.53      0.53        70
#
#
# ===== Fold 2 - Random_Forest - {'classifier__class_weight': 'balanced', 'classifier__max_depth': 3, 'classifier__max_features': 'sqrt', 'classifier__max_leaf_nodes': 4, 'classifier__min_samples_leaf': 5, 'classifier__n_estimators': 20} =====
# Accuracy: 0.5714
# Balanced Accuracy: 0.5409
# F1 Macro: 0.5411
# AUC: 0.5189
#
# Confusion matrix:
# [[29 14]
#  [16 11]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.64      0.67      0.66        43
#            1       0.44      0.41      0.42        27
#
#     accuracy                           0.57        70
#    macro avg       0.54      0.54      0.54        70
# weighted avg       0.57      0.57      0.57        70
#
# ['lh', 'estrogen', 'hr_mean', 'hr_median', 'hr_cv', 'hr_min', 'hr_q_05', 'hr_q_25', 'hr_q_75', 'hr_q_95', 'glucose_mean', 'glucose_median', 'glucose_std', 'glucose_var', 'glucose_min', 'glucose_max', 'glucose_q_05', 'glucose_q_25', 'glucose_q_75', 'glucose_q_95']
#
# ===== Fold 2 - SVM - {'classifier__C': 0.01, 'classifier__class_weight': 'balanced', 'classifier__gamma': 'scale', 'classifier__kernel': 'linear', 'feature_selection__k': 20} =====
# Accuracy: 0.5714
# Balanced Accuracy: 0.5409
# F1 Macro: 0.5411
# AUC: 0.5392
#
# Confusion matrix:
# [[29 14]
#  [16 11]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.64      0.67      0.66        43
#            1       0.44      0.41      0.42        27
#
#     accuracy                           0.57        70
#    macro avg       0.54      0.54      0.54        70
# weighted avg       0.57      0.57      0.57        70
#
# ['lh', 'glucose_mean', 'glucose_min', 'glucose_q_05', 'glucose_q_25']
#
# ===== Fold 3 - KNN - {'classifier__metric': 'euclidean', 'classifier__n_neighbors': 9, 'classifier__weights': 'uniform', 'feature_selection__k': 5} =====
# Accuracy: 0.4848
# Balanced Accuracy: 0.4758
# F1 Macro: 0.4629
# AUC: 0.4580
#
# Confusion matrix:
# [[34 34]
#  [17 14]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.67      0.50      0.57        68
#            1       0.29      0.45      0.35        31
#
#     accuracy                           0.48        99
#    macro avg       0.48      0.48      0.46        99
# weighted avg       0.55      0.48      0.50        99
#
# ['lh', 'hr_min', 'hr_q_05', 'hr_q_75', 'glucose_mean', 'glucose_median', 'glucose_min', 'glucose_q_05', 'glucose_q_25', 'glucose_q_75']
# Threshold:  0.5299950191501008
#
# ===== Fold 3 - LogReg_Youden - {'classifier__C': 1, 'classifier__class_weight': 'balanced', 'classifier__penalty': 'l1', 'feature_selection__k': 10} =====
# Accuracy: 0.5859
# Balanced Accuracy: 0.5844
# F1 Macro: 0.5643
# AUC: 0.6200
#
# Confusion matrix:
# [[40 28]
#  [13 18]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.75      0.59      0.66        68
#            1       0.39      0.58      0.47        31
#
#     accuracy                           0.59        99
#    macro avg       0.57      0.58      0.56        99
# weighted avg       0.64      0.59      0.60        99
#
# ['lh', 'hr_min', 'hr_q_05', 'hr_q_75', 'glucose_mean', 'glucose_median', 'glucose_min', 'glucose_q_05', 'glucose_q_25', 'glucose_q_75']
# Threshold:  0.5
#
# ===== Fold 3 - LogReg_Rho - {'classifier__C': 1, 'classifier__class_weight': 'balanced', 'classifier__penalty': 'l1', 'feature_selection__k': 10} =====
# Accuracy: 0.5960
# Balanced Accuracy: 0.6093
# F1 Macro: 0.5805
# AUC: 0.6200
#
# Confusion matrix:
# [[39 29]
#  [11 20]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.78      0.57      0.66        68
#            1       0.41      0.65      0.50        31
#
#     accuracy                           0.60        99
#    macro avg       0.59      0.61      0.58        99
# weighted avg       0.66      0.60      0.61        99
#
#
# ===== Fold 3 - Random_Forest - {'classifier__class_weight': 'balanced', 'classifier__max_depth': 7, 'classifier__max_features': 'sqrt', 'classifier__max_leaf_nodes': 32, 'classifier__min_samples_leaf': 1, 'classifier__n_estimators': 10} =====
# Accuracy: 0.5253
# Balanced Accuracy: 0.5140
# F1 Macro: 0.5006
# AUC: 0.4554
#
# Confusion matrix:
# [[37 31]
#  [16 15]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.70      0.54      0.61        68
#            1       0.33      0.48      0.39        31
#
#     accuracy                           0.53        99
#    macro avg       0.51      0.51      0.50        99
# weighted avg       0.58      0.53      0.54        99
#
# ['lh', 'glucose_mean', 'glucose_min', 'glucose_q_05', 'glucose_q_25']
#
# ===== Fold 3 - SVM - {'classifier__C': 10, 'classifier__class_weight': 'balanced', 'classifier__gamma': 'scale', 'classifier__kernel': 'linear', 'feature_selection__k': 5} =====
# Accuracy: 0.5657
# Balanced Accuracy: 0.5961
# F1 Macro: 0.5568
# AUC: 0.6006
#
# Confusion matrix:
# [[35 33]
#  [10 21]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.78      0.51      0.62        68
#            1       0.39      0.68      0.49        31
#
#     accuracy                           0.57        99
#    macro avg       0.58      0.60      0.56        99
# weighted avg       0.66      0.57      0.58        99
#
# ['hr_mean', 'hr_median', 'hr_min', 'hr_q_05', 'hr_q_25', 'glucose_mean', 'glucose_min', 'glucose_q_05', 'glucose_q_25', 'glucose_q_75']
#
# ===== Fold 4 - KNN - {'classifier__metric': 'manhattan', 'classifier__n_neighbors': 3, 'classifier__weights': 'uniform', 'feature_selection__k': 10} =====
# Accuracy: 0.5091
# Balanced Accuracy: 0.5010
# F1 Macro: 0.5010
# AUC: 0.4466
#
# Confusion matrix:
# [[35 27]
#  [27 21]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.56      0.56      0.56        62
#            1       0.44      0.44      0.44        48
#
#     accuracy                           0.51       110
#    macro avg       0.50      0.50      0.50       110
# weighted avg       0.51      0.51      0.51       110
#
# ['hr_mean', 'hr_median', 'hr_cv', 'hr_min', 'hr_q_05', 'hr_q_25', 'hr_q_75', 'hr_q_95', 'glucose_mean', 'glucose_median', 'glucose_min', 'glucose_q_05', 'glucose_q_25', 'glucose_q_75', 'glucose_q_95']
# Threshold:  0.5095597328047758
#
# ===== Fold 4 - LogReg_Youden - {'classifier__C': 0.001, 'classifier__class_weight': 'balanced', 'classifier__penalty': 'l2', 'feature_selection__k': 15} =====
# Accuracy: 0.6455
# Balanced Accuracy: 0.6243
# F1 Macro: 0.6227
# AUC: 0.6566
#
# Confusion matrix:
# [[49 13]
#  [26 22]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.65      0.79      0.72        62
#            1       0.63      0.46      0.53        48
#
#     accuracy                           0.65       110
#    macro avg       0.64      0.62      0.62       110
# weighted avg       0.64      0.65      0.63       110
#
# ['hr_mean', 'hr_median', 'hr_cv', 'hr_min', 'hr_q_05', 'hr_q_25', 'hr_q_75', 'hr_q_95', 'glucose_mean', 'glucose_median', 'glucose_min', 'glucose_q_05', 'glucose_q_25', 'glucose_q_75', 'glucose_q_95']
# Threshold:  0.5
#
# ===== Fold 4 - LogReg_Rho - {'classifier__C': 0.001, 'classifier__class_weight': 'balanced', 'classifier__penalty': 'l2', 'feature_selection__k': 15} =====
# Accuracy: 0.6455
# Balanced Accuracy: 0.6361
# F1 Macro: 0.6368
# AUC: 0.6566
#
# Confusion matrix:
# [[44 18]
#  [21 27]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.68      0.71      0.69        62
#            1       0.60      0.56      0.58        48
#
#     accuracy                           0.65       110
#    macro avg       0.64      0.64      0.64       110
# weighted avg       0.64      0.65      0.64       110
#
#
# ===== Fold 4 - Random_Forest - {'classifier__class_weight': 'balanced', 'classifier__max_depth': 1, 'classifier__max_features': 'log2', 'classifier__max_leaf_nodes': 2, 'classifier__min_samples_leaf': 1, 'classifier__n_estimators': 50} =====
# Accuracy: 0.6000
# Balanced Accuracy: 0.5581
# F1 Macro: 0.5238
# AUC: 0.6796
#
# Confusion matrix:
# [[55  7]
#  [37 11]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.60      0.89      0.71        62
#            1       0.61      0.23      0.33        48
#
#     accuracy                           0.60       110
#    macro avg       0.60      0.56      0.52       110
# weighted avg       0.60      0.60      0.55       110
#
# ['hr_mean', 'hr_median', 'hr_cv', 'hr_min', 'hr_q_05', 'hr_q_25', 'hr_q_75', 'hr_q_95', 'glucose_mean', 'glucose_median', 'glucose_min', 'glucose_q_05', 'glucose_q_25', 'glucose_q_75', 'glucose_q_95']
#
# ===== Fold 4 - SVM - {'classifier__C': 10, 'classifier__class_weight': 'balanced', 'classifier__gamma': 'auto', 'classifier__kernel': 'rbf', 'feature_selection__k': 15} =====
# Accuracy: 0.5000
# Balanced Accuracy: 0.4741
# F1 Macro: 0.4627
# AUC: 0.4913
#
# Confusion matrix:
# [[42 20]
#  [35 13]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.55      0.68      0.60        62
#            1       0.39      0.27      0.32        48
#
#     accuracy                           0.50       110
#    macro avg       0.47      0.47      0.46       110
# weighted avg       0.48      0.50      0.48       110
#
# ['hr_mean', 'hr_q_05', 'glucose_mean', 'glucose_min', 'glucose_q_75']
#
# ===== Fold 5 - KNN - {'classifier__metric': 'manhattan', 'classifier__n_neighbors': 7, 'classifier__weights': 'distance', 'feature_selection__k': 5} =====
# Accuracy: 0.4521
# Balanced Accuracy: 0.4300
# F1 Macro: 0.4279
# AUC: 0.4567
#
# Confusion matrix:
# [[24 24]
#  [16  9]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.60      0.50      0.55        48
#            1       0.27      0.36      0.31        25
#
#     accuracy                           0.45        73
#    macro avg       0.44      0.43      0.43        73
# weighted avg       0.49      0.45      0.46        73
#
# ['lh', 'estrogen', 'nightly_temperature', 'hr_mean', 'hr_median', 'hr_std', 'hr_cv', 'hr_var', 'hr_min', 'hr_max', 'hr_q_05', 'hr_q_25', 'hr_q_75', 'hr_q_95', 'glucose_mean', 'glucose_median', 'glucose_std', 'glucose_cv', 'glucose_var', 'glucose_min', 'glucose_max', 'glucose_q_05', 'glucose_q_25', 'glucose_q_75', 'glucose_q_95']
# Threshold:  0.5474610945417285
#
# ===== Fold 5 - LogReg_Youden - {'classifier__C': 0.01, 'classifier__class_weight': 'balanced', 'classifier__penalty': 'l2', 'feature_selection__k': 'all'} =====
# Accuracy: 0.5342
# Balanced Accuracy: 0.5596
# F1 Macro: 0.5299
# AUC: 0.5175
#
# Confusion matrix:
# [[23 25]
#  [ 9 16]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.72      0.48      0.57        48
#            1       0.39      0.64      0.48        25
#
#     accuracy                           0.53        73
#    macro avg       0.55      0.56      0.53        73
# weighted avg       0.61      0.53      0.54        73
#
# ['lh', 'estrogen', 'nightly_temperature', 'hr_mean', 'hr_median', 'hr_std', 'hr_cv', 'hr_var', 'hr_min', 'hr_max', 'hr_q_05', 'hr_q_25', 'hr_q_75', 'hr_q_95', 'glucose_mean', 'glucose_median', 'glucose_std', 'glucose_cv', 'glucose_var', 'glucose_min', 'glucose_max', 'glucose_q_05', 'glucose_q_25', 'glucose_q_75', 'glucose_q_95']
# Threshold:  0.55
#
# ===== Fold 5 - LogReg_Rho - {'classifier__C': 0.01, 'classifier__class_weight': 'balanced', 'classifier__penalty': 'l2', 'feature_selection__k': 'all'} =====
# Accuracy: 0.5205
# Balanced Accuracy: 0.5396
# F1 Macro: 0.5147
# AUC: 0.5175
#
# Confusion matrix:
# [[23 25]
#  [10 15]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.70      0.48      0.57        48
#            1       0.38      0.60      0.46        25
#
#     accuracy                           0.52        73
#    macro avg       0.54      0.54      0.51        73
# weighted avg       0.59      0.52      0.53        73
#
#
# ===== Fold 5 - Random_Forest - {'classifier__class_weight': 'balanced', 'classifier__max_depth': 1, 'classifier__max_features': 'log2', 'classifier__max_leaf_nodes': 2, 'classifier__min_samples_leaf': 10, 'classifier__n_estimators': 50} =====
# Accuracy: 0.4932
# Balanced Accuracy: 0.5475
# F1 Macro: 0.4932
# AUC: 0.5508
#
# Confusion matrix:
# [[18 30]
#  [ 7 18]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.72      0.38      0.49        48
#            1       0.38      0.72      0.49        25
#
#     accuracy                           0.49        73
#    macro avg       0.55      0.55      0.49        73
# weighted avg       0.60      0.49      0.49        73
#
# ['hr_mean', 'hr_min', 'hr_q_05', 'hr_q_25', 'hr_q_75', 'glucose_mean', 'glucose_median', 'glucose_min', 'glucose_q_75', 'glucose_q_95']
#
# ===== Fold 5 - SVM - {'classifier__C': 1, 'classifier__class_weight': 'balanced', 'classifier__gamma': 'scale', 'classifier__kernel': 'linear', 'feature_selection__k': 10} =====
# Accuracy: 0.4795
# Balanced Accuracy: 0.5563
# F1 Macro: 0.4770
# AUC: 0.4904
#
# Confusion matrix:
# [[15 33]
#  [ 5 20]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.75      0.31      0.44        48
#            1       0.38      0.80      0.51        25
#
#     accuracy                           0.48        73
#    macro avg       0.56      0.56      0.48        73
# weighted avg       0.62      0.48      0.47        73
#   Type response          Model                     Accuracy  \
# 0        cramps            KNN  0.55 +- 0.09 [0.45 -  0.69]
# 1                LogReg_Youden  0.59 +- 0.06 [0.50 -  0.67]
# 2                   LogReg_Rho  0.59 +- 0.05 [0.52 -  0.65]
# 3                Random_Forest  0.56 +- 0.04 [0.49 -  0.61]
# 4                          SVM  0.55 +- 0.06 [0.48 -  0.65]
#
#              Balanced Accuracy                F1-Score (macro)  \
# 0  0.53 +- 0.08 [0.43 -  0.63]  0.53 +- 0.08  [0.43  -   0.64]
# 1  0.58 +- 0.06 [0.48 -  0.66]  0.57 +- 0.06  [0.48  -   0.66]
# 2  0.58 +- 0.05 [0.50 -  0.64]  0.57 +- 0.06  [0.50  -   0.64]
# 3  0.55 +- 0.03 [0.51 -  0.60]  0.53 +- 0.04  [0.49  -   0.60]
# 4  0.56 +- 0.05 [0.47 -  0.63]  0.53 +- 0.06  [0.46  -   0.63]
#
#               F1-Score (weighted)                             AUC
# 0  0.56 +- 0.08  [0.46  -   0.67]  0.50 +- 0.07  [ 0.45  -  0.63]
# 1  0.59 +- 0.06  [0.50  -   0.67]  0.60 +- 0.06  [ 0.52  -  0.66]
# 2  0.59 +- 0.05  [0.53  -   0.64]  0.60 +- 0.06  [ 0.52  -  0.66]
# 3  0.55 +- 0.04  [0.49  -   0.61]  0.56 +- 0.08  [ 0.46  -  0.68]
# 4  0.55 +- 0.07  [0.47  -   0.65]  0.56 +- 0.06  [ 0.49  -  0.65]
