# %%
from sklearn import svm

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as stats
from sklearn.decomposition import PCA
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler as  StandardScaler
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, classification_report, balanced_accuracy_score
from sklearn.model_selection import KFold, cross_validate, cross_val_score, GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.model_selection import StratifiedKFold
from sklearn.feature_selection import SelectKBest, f_classif, SelectFromModel
from imblearn.pipeline import Pipeline as im_Pipeline
from sklearn.model_selection import StratifiedGroupKFold, cross_val_predict
from sklearn.metrics import roc_curve, confusion_matrix

# %%
df1 = pd.read_csv("master_tripel_cramps_dataset.csv")

df_ogmenstrual = df1[df1["phase"] == "Menstrual"].copy()

df_clean_menstrual_og = df_ogmenstrual.dropna(subset=[
    "cramps",
    "cramps binary",
    "cramps group",
    "phase",
    "lh",
    "estrogen",
    "nightly_temperature",
    "hr_mean",
    "glucose_median",
    "glucose_std"
]).copy()

cramps_map_menstrual = {
    "Not at all": 0,
    "Very Low/Little": 1,
    "Low": 2,
    "Moderate": 3,
    "High": 4,
    "Very High": 5
}

cramps_map_binary_menstrual = {
    "Low Pain": 0,
    "High Pain": 1,
}

cramps_map_group_menstrual = {
    "No Pain": 0,
    "Low Pain": 1,
    "High Pain": 2,
}

df_clean_menstrual_og["cramps"] = df_clean_menstrual_og["cramps"].map(cramps_map_menstrual)
df_clean_menstrual_og["cramps binary"] = df_clean_menstrual_og["cramps binary"].map(cramps_map_binary_menstrual)
df_clean_menstrual_og["cramps group"] = df_clean_menstrual_og["cramps group"].map(cramps_map_group_menstrual)

df_clean_menstrual_og = df_clean_menstrual_og.dropna(subset=["cramps binary"]).copy()
drop_cols = [
    "id",
    "phase",
    "cramps",
    "cramps binary",
    "cramps group",
    "study_interval_x",
    "study_interval_y",
    "day_in_study"
]

X = df_clean_menstrual_og.drop(columns=drop_cols)
y = df_clean_menstrual_og["cramps binary"].astype(int)

variables_num = X.columns.tolist()

# %%
groups = df_clean_menstrual_og["id"]

cv_outer = StratifiedGroupKFold(
    n_splits=5,
    shuffle=True,
    random_state=42
)

cv_inner = StratifiedGroupKFold(
    n_splits=5,
    shuffle=True,
    random_state=42
)

import pickle 
with open("outer_splits_menstrual_binary.pkl", "rb") as f:
    outer_splits = pickle.load(f)

def get_best_rho(y_train, y_train_proba_oof, rhos=np.linspace(0.1, 0.9, 17)):

    best_rho = None
    best_f1 = -1

    for rho in rhos:

        y_pred = (y_train_proba_oof >= rho).astype(int)

        f1 = f1_score(y_train, y_pred, average="macro")

        if f1 > best_f1:
            best_f1 = f1
            best_rho = rho

    return best_rho

# %%
param_grid = {"KNN": {
                    "classifier__n_neighbors": [3, 5, 7, 9, 11],
                    "classifier__weights": ["uniform", "distance"],
                    "classifier__metric": ["euclidean", "manhattan"],
                    "feature_selection__k": [5, 10, 15, 20, "all"]}, 
              "LogReg_Youden": {
                    "classifier__C": [0.001, 0.01, 0.1, 1, 10],
                    "classifier__class_weight": ["balanced"],
                    "classifier__penalty": ["l1", "l2"],
                    "feature_selection__k": [5, 10, 15, 20, "all"]},
              "LogReg_Rho": {
                    "classifier__C": [0.001, 0.01, 0.1, 1, 10],
                    "classifier__class_weight": ["balanced"],
                    "classifier__penalty": ["l1", "l2"],
                    "feature_selection__k": [5, 10, 15, 20, "all"]},
              "Random_Forest": {
                    "classifier__n_estimators": [10, 20, 50, 100, 200, 250, 300, 500],
                    "classifier__max_depth": [1, 2, 3, 5, 7, 10],
                    "classifier__min_samples_leaf": [1, 5, 10],
                    "classifier__max_features": ["sqrt", "log2"],
                    "classifier__max_leaf_nodes": [2, 4, 8, 16, 32],
                    "classifier__class_weight": ["balanced"]},
              "SVM":{
                    "classifier__kernel": ["linear","rbf"],
                    "classifier__gamma": ["scale", "auto"],
                    "classifier__C": [0.01, 0.1, 1, 10],
                    "classifier__class_weight": ["balanced"],
                    "feature_selection__k": [5, 10, 15, 20, "all"]}

    }

# %%
model_df = []
type_response_df = []
accuracy_model = []
balanced_accuracy_model = []
f1_macro_model = []
f1_weighted_model = []
AUC_model = []
models = ["KNN", "LogReg_Youden", "LogReg_Rho","Random_Forest","SVM"]


accuracy = np.nan * np.ones((len(models), len(outer_splits)))
balanced_accuracy = np.nan * np.ones((len(models), len(outer_splits)))
f1_macro = np.nan * np.ones((len(models), len(outer_splits)))
f1_weighted = np.nan * np.ones((len(models), len(outer_splits)))
auc = np.nan * np.ones((len(models), len(outer_splits)))

best_params_all = {model: [] for model in models}
selected_features_all = {model: [] for model in models}
thresholds_lr_youden = []
thresholds_lr_rho = []

for j, (train_idx, test_idx) in enumerate(outer_splits):
    X_train = X.iloc[train_idx]
    X_test = X.iloc[test_idx]

    y_train = y.iloc[train_idx]
    y_test = y.iloc[test_idx]

    groups_train = groups.iloc[train_idx]
        
    for (i,model) in enumerate(models):
        preprocessor = ColumnTransformer(
            transformers=[
                ("zscore", StandardScaler(), variables_num)
        ])
        match model:
            case "LogReg_Youden":
                mdl = LogisticRegression( solver = "saga", max_iter=1000, random_state = 42)
            case "LogReg_Rho":
                mdl = LogisticRegression( solver = "saga", max_iter=1000, random_state = 42)    
            case "Random_Forest":
                mdl = RandomForestClassifier(random_state = 42)
            case "KNN":
                mdl = KNeighborsClassifier()
            case "SVM":
                mdl = svm.SVC(probability = True, random_state = 42)
        if model == "Random_Forest":
            pipeline = Pipeline([
                ("preprocessor", preprocessor),
                ("classifier", mdl)])
        else:
            pipeline = Pipeline([
                ("preprocessor", preprocessor),
                ("feature_selection", SelectKBest(score_func=f_classif)),
                ("classifier", mdl)])

        grid = GridSearchCV(
                estimator=pipeline,
                param_grid=param_grid[model],
                cv=cv_inner,
                scoring="f1_macro",
                n_jobs=-1)
        
        grid.fit(X_train, y_train, groups=groups_train)
        
        mdl_selected = grid.best_estimator_
        best_params_all[model].append(grid.best_params_)
        
        if model != "Random_Forest":
            selector = mdl_selected.named_steps["feature_selection"]
            selected_features = X_train.columns[selector.get_support()].tolist()
            print(selected_features)
        else:
            selected_features = X_train.columns.tolist()

        selected_features_all[model].append(selected_features)

        if model == "LogReg_Youden":
            y_train_proba_oof = cross_val_predict(
                mdl_selected,
                X_train,
                y_train,
                cv=cv_inner,   # cv_outer, pero aplicado a X_train, y_train, groups_train. no debes hacer es reutilizar outer_splits dentro del GridSearch, porque esos índices son del dataset completo, no de X_train.
                groups=groups_train,
                method="predict_proba",
                n_jobs=-1
            )[:, 1]

            fpr, tpr, thresholds = roc_curve(y_train, y_train_proba_oof)
            youden_index = tpr - fpr
            best_threshold = thresholds[np.argmax(youden_index)]

            thresholds_lr_youden.append(best_threshold)
            print ("Threshold: ", best_threshold)

            mdl_selected.fit(X_train, y_train)
            y_prob = mdl_selected.predict_proba(X_test)[:, 1]
            y_pred = (y_prob >= best_threshold).astype(int)
            
        elif model == "LogReg_Rho":
            y_train_proba_oof = cross_val_predict(mdl_selected, X_train, y_train, cv=cv_inner, groups=groups_train, method="predict_proba", n_jobs=-1)[:, 1]
            rho_threshold = get_best_rho(y_train,y_train_proba_oof, rhos=np.linspace(0.1, 0.9, 17))

            thresholds_lr_rho.append(rho_threshold)
            print ("Threshold: ", rho_threshold)

            mdl_selected.fit(X_train, y_train)
            y_prob = mdl_selected.predict_proba(X_test)[:, 1]
            y_pred = (y_prob >= rho_threshold).astype(int)
        else:
            mdl_selected.fit(X_train, y_train)
            y_pred = mdl_selected.predict(X_test)
            y_prob = mdl_selected.predict_proba(X_test)[:, 1]
        
        accuracy[i, j] = accuracy_score(y_test, y_pred)
        balanced_accuracy[i, j] = balanced_accuracy_score(y_test, y_pred)
        f1_macro[i, j] = f1_score(y_test, y_pred, average="macro")
        f1_weighted[i, j] = f1_score(y_test, y_pred, average="weighted")
        auc[i, j] = roc_auc_score(y_test, y_prob)

        cm = confusion_matrix(y_test, y_pred)

        print(f"\n===== Fold {j+1} - {model} - {grid.best_params_} =====")
        print(f"Accuracy: {accuracy[i,j]:.4f}")
        print(f"Balanced Accuracy: {balanced_accuracy[i,j]:.4f}")
        print(f"F1 Macro: {f1_macro[i,j]:.4f}")
        print(f"AUC: {auc[i,j]:.4f}")

        print("\nConfusion matrix:")
        print(cm)

        print("\nClassification report:")
        print(classification_report(y_test, y_pred))
        
for (i,model) in enumerate(models):
    accuracy_model.append(f"{np.mean(accuracy[i,:]):.2f} +- {np.std(accuracy[i,:]):.2f} [{np.min(accuracy[i,:]):.2f} -  {np.max(accuracy[i,:]):.2f}]")
    balanced_accuracy_model.append(f"{np.mean(balanced_accuracy[i,:]):.2f} +- {np.std(balanced_accuracy[i,:]):.2f} [{np.min(balanced_accuracy[i,:]):.2f} -  {np.max(balanced_accuracy[i,:]):.2f}]")
    f1_macro_model.append(f"{np.mean(f1_macro[i,:]):.2f} +- {np.std(f1_macro[i,:]):.2f}  [{np.min(f1_macro[i,:]):.2f}  -   {np.max(f1_macro[i,:]):.2f}]")
    f1_weighted_model.append(f"{np.mean(f1_weighted[i,:]):.2f} +- {np.std(f1_weighted[i,:]):.2f}  [{np.min(f1_weighted[i,:]):.2f}  -   {np.max(f1_weighted[i,:]):.2f}]")
    AUC_model.append(f"{np.mean(auc[i,:]):.2f} +- {np.std(auc[i,:]):.2f}  [ {np.min(auc[i,:]):.2f}  -  {np.max(auc[i,:]):.2f}]")
        
    if i == 0:
        type_response_df.append("cramps")
    else:
        type_response_df.append("")
        
    model_df.append(model)


df_performance_models = pd.DataFrame(np.transpose([type_response_df,model_df,accuracy_model,balanced_accuracy_model,f1_macro_model,f1_weighted_model, AUC_model]), columns=["Type response","Model", "Accuracy","Balanced Accuracy","F1-Score (macro)","F1-Score (weighted)","AUC"])
display(df_performance_models)
# Out:
# ['lh', 'glucose_mean', 'glucose_min', 'glucose_q_75', 'glucose_q_95']
#
# ===== Fold 1 - KNN - {'classifier__metric': 'euclidean', 'classifier__n_neighbors': 11, 'classifier__weights': 'uniform', 'feature_selection__k': 5} =====
# Accuracy: 0.5841
# Balanced Accuracy: 0.5154
# F1 Macro: 0.4828
# AUC: 0.5572
#
# Confusion matrix:
# [[58 10]
#  [37  8]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.61      0.85      0.71        68
#            1       0.44      0.18      0.25        45
#
#     accuracy                           0.58       113
#    macro avg       0.53      0.52      0.48       113
# weighted avg       0.54      0.58      0.53       113
#
# ['lh', 'glucose_mean', 'glucose_min', 'glucose_q_75', 'glucose_q_95']
# Threshold:  0.49749868508002476
#
# ===== Fold 1 - LogReg_Youden - {'classifier__C': 0.001, 'classifier__class_weight': 'balanced', 'classifier__penalty': 'l2', 'feature_selection__k': 5} =====
# Accuracy: 0.5487
# Balanced Accuracy: 0.5649
# F1 Macro: 0.5481
# AUC: 0.6059
#
# Confusion matrix:
# [[33 35]
#  [16 29]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.67      0.49      0.56        68
#            1       0.45      0.64      0.53        45
#
#     accuracy                           0.55       113
#    macro avg       0.56      0.56      0.55       113
# weighted avg       0.59      0.55      0.55       113
#
# ['lh', 'glucose_mean', 'glucose_min', 'glucose_q_75', 'glucose_q_95']
# Threshold:  0.5
#
# ===== Fold 1 - LogReg_Rho - {'classifier__C': 0.001, 'classifier__class_weight': 'balanced', 'classifier__penalty': 'l2', 'feature_selection__k': 5} =====
# Accuracy: 0.5664
# Balanced Accuracy: 0.5721
# F1 Macro: 0.5629
# AUC: 0.6059
#
# Confusion matrix:
# [[37 31]
#  [18 27]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.67      0.54      0.60        68
#            1       0.47      0.60      0.52        45
#
#     accuracy                           0.57       113
#    macro avg       0.57      0.57      0.56       113
# weighted avg       0.59      0.57      0.57       113
#
#
# ===== Fold 1 - Random_Forest - {'classifier__class_weight': 'balanced', 'classifier__max_depth': 10, 'classifier__max_features': 'log2', 'classifier__max_leaf_nodes': 16, 'classifier__min_samples_leaf': 5, 'classifier__n_estimators': 10} =====
# Accuracy: 0.5310
# Balanced Accuracy: 0.5163
# F1 Macro: 0.5158
# AUC: 0.5536
#
# Confusion matrix:
# [[40 28]
#  [25 20]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.62      0.59      0.60        68
#            1       0.42      0.44      0.43        45
#
#     accuracy                           0.53       113
#    macro avg       0.52      0.52      0.52       113
# weighted avg       0.54      0.53      0.53       113
#
# ['lh', 'glucose_mean', 'glucose_min', 'glucose_q_75', 'glucose_q_95']
#
# ===== Fold 1 - SVM - {'classifier__C': 10, 'classifier__class_weight': 'balanced', 'classifier__gamma': 'scale', 'classifier__kernel': 'linear', 'feature_selection__k': 5} =====
# Accuracy: 0.6106
# Balanced Accuracy: 0.6088
# F1 Macro: 0.6036
# AUC: 0.5843
#
# Confusion matrix:
# [[42 26]
#  [18 27]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.70      0.62      0.66        68
#            1       0.51      0.60      0.55        45
#
#     accuracy                           0.61       113
#    macro avg       0.60      0.61      0.60       113
# weighted avg       0.62      0.61      0.61       113
#
# ['glucose_mean', 'glucose_median', 'glucose_min', 'glucose_q_25', 'glucose_q_75']
#
# ===== Fold 2 - KNN - {'classifier__metric': 'manhattan', 'classifier__n_neighbors': 3, 'classifier__weights': 'distance', 'feature_selection__k': 5} =====
# Accuracy: 0.5286
# Balanced Accuracy: 0.4716
# F1 Macro: 0.4596
# AUC: 0.4285
#
# Confusion matrix:
# [[31 12]
#  [21  6]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.60      0.72      0.65        43
#            1       0.33      0.22      0.27        27
#
#     accuracy                           0.53        70
#    macro avg       0.46      0.47      0.46        70
# weighted avg       0.49      0.53      0.50        70
#
# ['lh', 'hr_mean', 'hr_median', 'hr_min', 'hr_q_05', 'hr_q_25', 'hr_q_75', 'glucose_mean', 'glucose_median', 'glucose_min', 'glucose_max', 'glucose_q_05', 'glucose_q_25', 'glucose_q_75', 'glucose_q_95']
# Threshold:  0.4132762247216032
#
# ===== Fold 2 - LogReg_Youden - {'classifier__C': 0.1, 'classifier__class_weight': 'balanced', 'classifier__penalty': 'l2', 'feature_selection__k': 15} =====
# Accuracy: 0.5429
# Balanced Accuracy: 0.5452
# F1 Macro: 0.5368
# AUC: 0.5349
#
# Confusion matrix:
# [[23 20]
#  [12 15]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.66      0.53      0.59        43
#            1       0.43      0.56      0.48        27
#
#     accuracy                           0.54        70
#    macro avg       0.54      0.55      0.54        70
# weighted avg       0.57      0.54      0.55        70
#
# ['lh', 'hr_mean', 'hr_median', 'hr_min', 'hr_q_05', 'hr_q_25', 'hr_q_75', 'glucose_mean', 'glucose_median', 'glucose_min', 'glucose_max', 'glucose_q_05', 'glucose_q_25', 'glucose_q_75', 'glucose_q_95']
# Threshold:  0.5
#
# ===== Fold 2 - LogReg_Rho - {'classifier__C': 0.1, 'classifier__class_weight': 'balanced', 'classifier__penalty': 'l2', 'feature_selection__k': 15} =====
# Accuracy: 0.5143
# Balanced Accuracy: 0.4806
# F1 Macro: 0.4799
# AUC: 0.5349
#
# Confusion matrix:
# [[27 16]
#  [18  9]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.60      0.63      0.61        43
#            1       0.36      0.33      0.35        27
#
#     accuracy                           0.51        70
#    macro avg       0.48      0.48      0.48        70
# weighted avg       0.51      0.51      0.51        70
#
#
# ===== Fold 2 - Random_Forest - {'classifier__class_weight': 'balanced', 'classifier__max_depth': 2, 'classifier__max_features': 'log2', 'classifier__max_leaf_nodes': 4, 'classifier__min_samples_leaf': 10, 'classifier__n_estimators': 50} =====
# Accuracy: 0.6143
# Balanced Accuracy: 0.5827
# F1 Macro: 0.5836
# AUC: 0.5702
#
# Confusion matrix:
# [[31 12]
#  [15 12]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.67      0.72      0.70        43
#            1       0.50      0.44      0.47        27
#
#     accuracy                           0.61        70
#    macro avg       0.59      0.58      0.58        70
# weighted avg       0.61      0.61      0.61        70
#
# ['lh', 'hr_mean', 'hr_median', 'hr_min', 'hr_q_05', 'hr_q_25', 'hr_q_75', 'glucose_mean', 'glucose_median', 'glucose_min', 'glucose_max', 'glucose_q_05', 'glucose_q_25', 'glucose_q_75', 'glucose_q_95']
#
# ===== Fold 2 - SVM - {'classifier__C': 0.1, 'classifier__class_weight': 'balanced', 'classifier__gamma': 'scale', 'classifier__kernel': 'linear', 'feature_selection__k': 15} =====
# Accuracy: 0.5286
# Balanced Accuracy: 0.4991
# F1 Macro: 0.4990
# AUC: 0.5426
#
# Confusion matrix:
# [[27 16]
#  [17 10]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.61      0.63      0.62        43
#            1       0.38      0.37      0.38        27
#
#     accuracy                           0.53        70
#    macro avg       0.50      0.50      0.50        70
# weighted avg       0.53      0.53      0.53        70
#
# ['lh', 'estrogen', 'hr_mean', 'hr_min', 'hr_q_05', 'hr_q_25', 'hr_q_75', 'glucose_mean', 'glucose_median', 'glucose_min', 'glucose_max', 'glucose_q_05', 'glucose_q_25', 'glucose_q_75', 'glucose_q_95']
#
# ===== Fold 3 - KNN - {'classifier__metric': 'euclidean', 'classifier__n_neighbors': 9, 'classifier__weights': 'uniform', 'feature_selection__k': 15} =====
# Accuracy: 0.6162
# Balanced Accuracy: 0.5451
# F1 Macro: 0.5457
# AUC: 0.5152
#
# Confusion matrix:
# [[50 18]
#  [20 11]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.71      0.74      0.72        68
#            1       0.38      0.35      0.37        31
#
#     accuracy                           0.62        99
#    macro avg       0.55      0.55      0.55        99
# weighted avg       0.61      0.62      0.61        99
#
# ['lh', 'estrogen', 'hr_mean', 'hr_min', 'hr_q_05', 'hr_q_25', 'hr_q_75', 'glucose_mean', 'glucose_median', 'glucose_min', 'glucose_max', 'glucose_q_05', 'glucose_q_25', 'glucose_q_75', 'glucose_q_95']
# Threshold:  0.505648637546202
#
# ===== Fold 3 - LogReg_Youden - {'classifier__C': 0.01, 'classifier__class_weight': 'balanced', 'classifier__penalty': 'l2', 'feature_selection__k': 15} =====
# Accuracy: 0.6465
# Balanced Accuracy: 0.6461
# F1 Macro: 0.6244
# AUC: 0.6689
#
# Confusion matrix:
# [[44 24]
#  [11 20]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.65      0.72        68
#            1       0.45      0.65      0.53        31
#
#     accuracy                           0.65        99
#    macro avg       0.63      0.65      0.62        99
# weighted avg       0.69      0.65      0.66        99
#
# ['lh', 'estrogen', 'hr_mean', 'hr_min', 'hr_q_05', 'hr_q_25', 'hr_q_75', 'glucose_mean', 'glucose_median', 'glucose_min', 'glucose_max', 'glucose_q_05', 'glucose_q_25', 'glucose_q_75', 'glucose_q_95']
# Threshold:  0.5
#
# ===== Fold 3 - LogReg_Rho - {'classifier__C': 0.01, 'classifier__class_weight': 'balanced', 'classifier__penalty': 'l2', 'feature_selection__k': 15} =====
# Accuracy: 0.6566
# Balanced Accuracy: 0.6622
# F1 Macro: 0.6370
# AUC: 0.6689
#
# Confusion matrix:
# [[44 24]
#  [10 21]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.81      0.65      0.72        68
#            1       0.47      0.68      0.55        31
#
#     accuracy                           0.66        99
#    macro avg       0.64      0.66      0.64        99
# weighted avg       0.71      0.66      0.67        99
#
#
# ===== Fold 3 - Random_Forest - {'classifier__class_weight': 'balanced', 'classifier__max_depth': 7, 'classifier__max_features': 'log2', 'classifier__max_leaf_nodes': 16, 'classifier__min_samples_leaf': 1, 'classifier__n_estimators': 50} =====
# Accuracy: 0.5657
# Balanced Accuracy: 0.4995
# F1 Macro: 0.4995
# AUC: 0.5047
#
# Confusion matrix:
# [[46 22]
#  [21 10]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.69      0.68      0.68        68
#            1       0.31      0.32      0.32        31
#
#     accuracy                           0.57        99
#    macro avg       0.50      0.50      0.50        99
# weighted avg       0.57      0.57      0.57        99
#
# ['lh', 'hr_mean', 'hr_min', 'hr_q_05', 'glucose_mean', 'glucose_median', 'glucose_min', 'glucose_q_05', 'glucose_q_25', 'glucose_q_75']
#
# ===== Fold 3 - SVM - {'classifier__C': 1, 'classifier__class_weight': 'balanced', 'classifier__gamma': 'scale', 'classifier__kernel': 'linear', 'feature_selection__k': 10} =====
# Accuracy: 0.6263
# Balanced Accuracy: 0.6577
# F1 Macro: 0.6162
# AUC: 0.6777
#
# Confusion matrix:
# [[39 29]
#  [ 8 23]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.57      0.68        68
#            1       0.44      0.74      0.55        31
#
#     accuracy                           0.63        99
#    macro avg       0.64      0.66      0.62        99
# weighted avg       0.71      0.63      0.64        99
#
# ['lh', 'hr_mean', 'hr_median', 'hr_cv', 'hr_min', 'hr_q_05', 'hr_q_25', 'hr_q_75', 'hr_q_95', 'glucose_mean', 'glucose_median', 'glucose_min', 'glucose_q_05', 'glucose_q_25', 'glucose_q_75']
#
# ===== Fold 4 - KNN - {'classifier__metric': 'manhattan', 'classifier__n_neighbors': 5, 'classifier__weights': 'uniform', 'feature_selection__k': 15} =====
# Accuracy: 0.6000
# Balanced Accuracy: 0.5581
# F1 Macro: 0.5238
# AUC: 0.5744
#
# Confusion matrix:
# [[55  7]
#  [37 11]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.60      0.89      0.71        62
#            1       0.61      0.23      0.33        48
#
#     accuracy                           0.60       110
#    macro avg       0.60      0.56      0.52       110
# weighted avg       0.60      0.60      0.55       110
#
# ['lh', 'hr_mean', 'hr_median', 'hr_cv', 'hr_min', 'hr_q_05', 'hr_q_25', 'hr_q_75', 'hr_q_95', 'glucose_mean', 'glucose_median', 'glucose_min', 'glucose_q_05', 'glucose_q_25', 'glucose_q_75']
# Threshold:  0.5071106766090461
#
# ===== Fold 4 - LogReg_Youden - {'classifier__C': 0.001, 'classifier__class_weight': 'balanced', 'classifier__penalty': 'l2', 'feature_selection__k': 15} =====
# Accuracy: 0.6455
# Balanced Accuracy: 0.6267
# F1 Macro: 0.6261
# AUC: 0.6623
#
# Confusion matrix:
# [[48 14]
#  [25 23]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.66      0.77      0.71        62
#            1       0.62      0.48      0.54        48
#
#     accuracy                           0.65       110
#    macro avg       0.64      0.63      0.63       110
# weighted avg       0.64      0.65      0.64       110
#
# ['lh', 'hr_mean', 'hr_median', 'hr_cv', 'hr_min', 'hr_q_05', 'hr_q_25', 'hr_q_75', 'hr_q_95', 'glucose_mean', 'glucose_median', 'glucose_min', 'glucose_q_05', 'glucose_q_25', 'glucose_q_75']
# Threshold:  0.5
#
# ===== Fold 4 - LogReg_Rho - {'classifier__C': 0.001, 'classifier__class_weight': 'balanced', 'classifier__penalty': 'l2', 'feature_selection__k': 15} =====
# Accuracy: 0.6545
# Balanced Accuracy: 0.6465
# F1 Macro: 0.6471
# AUC: 0.6623
#
# Confusion matrix:
# [[44 18]
#  [20 28]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.69      0.71      0.70        62
#            1       0.61      0.58      0.60        48
#
#     accuracy                           0.65       110
#    macro avg       0.65      0.65      0.65       110
# weighted avg       0.65      0.65      0.65       110
#
#
# ===== Fold 4 - Random_Forest - {'classifier__class_weight': 'balanced', 'classifier__max_depth': 1, 'classifier__max_features': 'log2', 'classifier__max_leaf_nodes': 2, 'classifier__min_samples_leaf': 1, 'classifier__n_estimators': 20} =====
# Accuracy: 0.6000
# Balanced Accuracy: 0.5605
# F1 Macro: 0.5317
# AUC: 0.6727
#
# Confusion matrix:
# [[54  8]
#  [36 12]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.60      0.87      0.71        62
#            1       0.60      0.25      0.35        48
#
#     accuracy                           0.60       110
#    macro avg       0.60      0.56      0.53       110
# weighted avg       0.60      0.60      0.55       110
#
# ['hr_mean', 'hr_median', 'hr_min', 'hr_q_05', 'hr_q_25', 'glucose_mean', 'glucose_min', 'glucose_q_05', 'glucose_q_25', 'glucose_q_75']
#
# ===== Fold 4 - SVM - {'classifier__C': 0.01, 'classifier__class_weight': 'balanced', 'classifier__gamma': 'scale', 'classifier__kernel': 'linear', 'feature_selection__k': 10} =====
# Accuracy: 0.6273
# Balanced Accuracy: 0.5988
# F1 Macro: 0.5904
# AUC: 0.6277
#
# Confusion matrix:
# [[51 11]
#  [30 18]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.63      0.82      0.71        62
#            1       0.62      0.38      0.47        48
#
#     accuracy                           0.63       110
#    macro avg       0.63      0.60      0.59       110
# weighted avg       0.63      0.63      0.61       110
#
# ['hr_mean', 'hr_min', 'hr_q_05', 'glucose_mean', 'glucose_median', 'glucose_min', 'glucose_q_05', 'glucose_q_25', 'glucose_q_75', 'glucose_q_95']
#
# ===== Fold 5 - KNN - {'classifier__metric': 'manhattan', 'classifier__n_neighbors': 9, 'classifier__weights': 'distance', 'feature_selection__k': 10} =====
# Accuracy: 0.5890
# Balanced Accuracy: 0.4958
# F1 Macro: 0.4835
# AUC: 0.4733
#
# Confusion matrix:
# [[38 10]
#  [20  5]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.66      0.79      0.72        48
#            1       0.33      0.20      0.25        25
#
#     accuracy                           0.59        73
#    macro avg       0.49      0.50      0.48        73
# weighted avg       0.54      0.59      0.56        73
#
# ['lh', 'estrogen', 'nightly_temperature', 'hr_mean', 'hr_median', 'hr_std', 'hr_cv', 'hr_var', 'hr_min', 'hr_max', 'hr_q_05', 'hr_q_25', 'hr_q_75', 'hr_q_95', 'glucose_mean', 'glucose_median', 'glucose_std', 'glucose_cv', 'glucose_var', 'glucose_min', 'glucose_max', 'glucose_q_05', 'glucose_q_25', 'glucose_q_75', 'glucose_q_95']
# Threshold:  0.48394464428994727
#
# ===== Fold 5 - LogReg_Youden - {'classifier__C': 0.01, 'classifier__class_weight': 'balanced', 'classifier__penalty': 'l2', 'feature_selection__k': 'all'} =====
# Accuracy: 0.4795
# Balanced Accuracy: 0.5658
# F1 Macro: 0.4746
# AUC: 0.5317
#
# Confusion matrix:
# [[14 34]
#  [ 4 21]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.78      0.29      0.42        48
#            1       0.38      0.84      0.53        25
#
#     accuracy                           0.48        73
#    macro avg       0.58      0.57      0.47        73
# weighted avg       0.64      0.48      0.46        73
#
# ['lh', 'estrogen', 'nightly_temperature', 'hr_mean', 'hr_median', 'hr_std', 'hr_cv', 'hr_var', 'hr_min', 'hr_max', 'hr_q_05', 'hr_q_25', 'hr_q_75', 'hr_q_95', 'glucose_mean', 'glucose_median', 'glucose_std', 'glucose_cv', 'glucose_var', 'glucose_min', 'glucose_max', 'glucose_q_05', 'glucose_q_25', 'glucose_q_75', 'glucose_q_95']
# Threshold:  0.55
#
# ===== Fold 5 - LogReg_Rho - {'classifier__C': 0.01, 'classifier__class_weight': 'balanced', 'classifier__penalty': 'l2', 'feature_selection__k': 'all'} =====
# Accuracy: 0.5479
# Balanced Accuracy: 0.5508
# F1 Macro: 0.5354
# AUC: 0.5317
#
# Confusion matrix:
# [[26 22]
#  [11 14]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.70      0.54      0.61        48
#            1       0.39      0.56      0.46        25
#
#     accuracy                           0.55        73
#    macro avg       0.55      0.55      0.54        73
# weighted avg       0.60      0.55      0.56        73
#
#
# ===== Fold 5 - Random_Forest - {'classifier__class_weight': 'balanced', 'classifier__max_depth': 3, 'classifier__max_features': 'log2', 'classifier__max_leaf_nodes': 4, 'classifier__min_samples_leaf': 1, 'classifier__n_estimators': 10} =====
# Accuracy: 0.4521
# Balanced Accuracy: 0.4683
# F1 Macro: 0.4470
# AUC: 0.4908
#
# Confusion matrix:
# [[20 28]
#  [12 13]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.62      0.42      0.50        48
#            1       0.32      0.52      0.39        25
#
#     accuracy                           0.45        73
#    macro avg       0.47      0.47      0.45        73
# weighted avg       0.52      0.45      0.46        73
#
# ['lh', 'estrogen', 'nightly_temperature', 'hr_mean', 'hr_median', 'hr_std', 'hr_cv', 'hr_var', 'hr_min', 'hr_max', 'hr_q_05', 'hr_q_25', 'hr_q_75', 'hr_q_95', 'glucose_mean', 'glucose_median', 'glucose_std', 'glucose_cv', 'glucose_var', 'glucose_min', 'glucose_max', 'glucose_q_05', 'glucose_q_25', 'glucose_q_75', 'glucose_q_95']
#
# ===== Fold 5 - SVM - {'classifier__C': 0.1, 'classifier__class_weight': 'balanced', 'classifier__gamma': 'scale', 'classifier__kernel': 'linear', 'feature_selection__k': 'all'} =====
# Accuracy: 0.5342
# Balanced Accuracy: 0.5883
# F1 Macro: 0.5342
# AUC: 0.6025
#
# Confusion matrix:
# [[20 28]
#  [ 6 19]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.77      0.42      0.54        48
#            1       0.40      0.76      0.53        25
#
#     accuracy                           0.53        73
#    macro avg       0.59      0.59      0.53        73
# weighted avg       0.64      0.53      0.54        73
#   Type response          Model                     Accuracy  \
# 0        cramps            KNN  0.58 +- 0.03 [0.53 -  0.62]
# 1                LogReg_Youden  0.57 +- 0.06 [0.48 -  0.65]
# 2                   LogReg_Rho  0.59 +- 0.06 [0.51 -  0.66]
# 3                Random_Forest  0.55 +- 0.06 [0.45 -  0.61]
# 4                          SVM  0.59 +- 0.04 [0.53 -  0.63]
#
#              Balanced Accuracy                F1-Score (macro)  \
# 0  0.52 +- 0.03 [0.47 -  0.56]  0.50 +- 0.03  [0.46  -   0.55]
# 1  0.59 +- 0.04 [0.55 -  0.65]  0.56 +- 0.06  [0.47  -   0.63]
# 2  0.58 +- 0.07 [0.48 -  0.66]  0.57 +- 0.06  [0.48  -   0.65]
# 3  0.53 +- 0.04 [0.47 -  0.58]  0.52 +- 0.04  [0.45  -   0.58]
# 4  0.59 +- 0.05 [0.50 -  0.66]  0.57 +- 0.04  [0.50  -   0.62]
#
#               F1-Score (weighted)                             AUC
# 0  0.55 +- 0.04  [0.50  -   0.61]  0.51 +- 0.05  [ 0.43  -  0.57]
# 1  0.57 +- 0.07  [0.46  -   0.66]  0.60 +- 0.06  [ 0.53  -  0.67]
# 2  0.59 +- 0.06  [0.51  -   0.67]  0.60 +- 0.06  [ 0.53  -  0.67]
# 3  0.55 +- 0.05  [0.46  -   0.61]  0.56 +- 0.06  [ 0.49  -  0.67]
# 4  0.58 +- 0.04  [0.53  -   0.64]  0.61 +- 0.04  [ 0.54  -  0.68]
